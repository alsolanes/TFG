# %% [markdown]
# #1.- Create a database with all cities and towns from Catalonia

# %% [markdown]
# As the project focuses on a database of news from diferent newspapers from Catalonia, the database will contain every town and city of Catalonia. This information will be extracted from a database given by the "Institut Cartogràfic de Catalunya".

# %%
# Initialize a MongoDB instance
from pymongo import MongoClient

def get_db_ciutats():
    client = MongoClient('localhost:27017')
    db = client.ciutats
    return db

def add_city_db(db, name, tipus, lat, lon):
    db.ciutats.insert({"name":name, "tipus":tipus,"lat":lat, "lon":lon})

# %%
import xlrd
from collections import OrderedDict
import simplejson as json
import utm

def ini_Catalan_cities():
    print "Loading file..."
    # Open the workbook and select the first worksheet
    wb = xlrd.open_workbook('CartoCat.xlsx')
    sh = wb.sheet_by_index(0)
    print "File loaded correctly."
    db = get_db_ciutats()
    
    print "Conversio iniciada"
    # Iterate through each row in worksheet and fetch values into dict
    for rownum in range(1, sh.nrows):
        item = OrderedDict()
        row_values = sh.row_values(rownum)
        item['nom'] = row_values[0]
        item['tipus'] = row_values[1]
        #item['municipi'] = row_values[2]
        #item['comarca'] = row_values[6]
        item['utmX'] = row_values[15]
        item['utmY'] = row_values[16]
        #if item['tipus']!= 'cap':
        #    continue
        if item['utmX']==0.0 or item['utmY']==0.0:
            continue
        #if db.ciutats.find({'name':item['nom']}).count()>0:
            #continue
        u = utm.to_latlon(item['utmX'],item['utmY'], 31, 'T')
        item['lat'] = u[0]
        item['lon'] = u[1]
        add_city_db(db,item['nom'],item['tipus'],item['lat'],item['lon'])
    print "Conversio finalitzada"
    print "Elements in db.ciutats: " , db.ciutats.count()

# %%
# Create the first database, the one containing all Catalan cities
# The following code should be executed once, so to prevent accidental execution and because of the long time
# the code lasts it is commented:

#ini_Catalan_cities()
# Out:
# Loading file...
# File loaded correctly.
# Conversio iniciada
# Conversio finalitzada
# Elements in db.ciutats:  52698

# %% [markdown]
# ## Query example
# Example of how a MongoDB can be queried to find an item by a key.

# %%
# Get the information related to my town: Calaf
db = get_db_ciutats()
poble = db.ciutats.find({'name':'Calaf'})
for a in poble:
    print a
# Out:
# {u'lat': 41.734805925564594, u'_id': ObjectId('554f9478366044344065476a'), u'lon': 1.5137381450247307, u'name': u'Calaf', u'tipus': u'cap'}

# %%
# Get the full list of towns and cities in Catalonia. There are currently 947 towns in Catalonia, so we expect
# a list of towns as long as that.
db = get_db_ciutats()
db.ciutats.find().count()
ciut = db.ciutats.find({'tipus':'cap'})
print ciut.count()
all_city_names = []
for a in ciut:
    print a['name']
    all_city_names.append(a['name'])
# Out:
# 947
# Abella, l'
# Abella de la Conca
# Abrera
# Àger
# Agramunt
# Aguilar de Segarra
# Agullana
# Aiguafreda
# Aiguaviva
# Aitona
# Alamús, els
# Alàs
# Albagés, l'
# Albanyà
# Albatàrrec
# Albesa
# Albi, l'
# Albinyana
# Albiol, l'
# Albons
# Alcanar
# Alcanó
# Alcarràs
# Alcoletge
# Alcover
# Aldea, l'
# Aldover
# Aleixar, l'
# Alella
# Alfara de Carles
# Alfarràs
# Alfés
# Alforja
# Algerri
# Alguaire
# Alins
# Alió
# All
# Almacelles
# Almatret
# Almenar
# Almoster
# Alòs de Balaguer
# Alp
# Alpens
# Alpicat
# Altafulla
# Amer
# Ametlla del Vallès, l'
# Ametlla de Mar, l'
# Ampolla, l'
# Amposta
# Anglès
# Anglesola
# Anserall
# Ansovell
# Arbeca
# Arboç, l'
# Arbolí
# Arbúcies
# Arenys de Mar
# Arenys de Munt
# Argelaguer
# Argençola
# Argentera, l'
# Argentona
# Armentera, l'
# Arnes
# Arres de Jos
# Arsèguel
# Artés
# Artesa de Lleida
# Artesa de Segre
# Ascó
# Aspa
# Avellanes, les
# Avià
# Avinyó
# Avinyonet de Puigventós
# Avinyó Nou
# Badalona
# Badia del Vallès
# Bagà
# Balaguer
# Balsareny
# Banyeres del Penedès
# Banyoles
# Barbens
# Barberà de la Conca
# Barberà del Vallès
# Barcelona
# Barruera
# Bàscara
# Bassella
# Batea
# Bausen
# Begues
# Begur
# Belianes
# Bellaguarda
# Bellcaire d'Empordà
# Bellcaire d'Urgell
# Bell-lloc d'Urgell
# Bellmunt del Priorat
# Bellmunt d'Urgell
# Bellprat
# Bellpuig
# Bellvei
# Bellver de Cerdanya
# Bellvís
# Benavent de Segrià
# Benifallet
# Benissanet
# Berga
# Besalú
# Bescanó
# Beuda
# Bigues
# Biosca
# Bisbal de Falset, la
# Bisbal del Penedès, la
# Bisbal d'Empordà, la
# Biure
# Blancafort
# Blanes
# Boadella d'Empordà
# Bolvir
# Bonastre
# Bonmatí
# Bòrdes, Es
# Bordils
# Borges Blanques, les
# Borges del Camp, les
# Borràs, el
# Borrassà
# Borredà
# Bossòst
# Bot
# Botarell
# Bou, Can
# Bovera
# Bràfim
# Branques, Can
# Breda
# Bruc, el
# Brull, el
# Brunyola
# Burg
# Cabacés *
# Cabanabona
# Cabanelles
# Cabanes
# Cabanyes, les
# Cabó
# Cabra del Camp
# Cabrera de Mar
# Cabrils
# Cadaqués
# Calaf
# Calafell
# Calders
# Caldes de Malavella
# Caldes de Montbui
# Caldes d'Estrac
# Calella
# Calldetenes
# Callús
# Calonge
# Camallera
# Camarasa
# Camarles
# Cambrils
# Cambrils
# Camós
# Campdevànol
# Campelles
# Campins
# Campllong
# Camprodon
# Canaletes
# Canejan
# Canet d'Adri
# Canet de Mar
# Canonja, la
# Canovelles
# Cànoves
# Cantallops
# Canyelles
# Capafonts
# Capçanes
# Capellades
# Capmany *
# Capolat
# Cardedeu
# Cardona
# Carme
# Caseres
# Cassà de la Selva
# Casserres
# Castellar de la Ribera
# Castellar del Vallès
# Castellar de n'Hug
# Castellbisbal
# Castellcir
# Castelldans
# Castelldefels
# Castell de l'Areny
# Castellfollit de la Roca
# Castellfollit del Boix
# Castellfollit de Riubregós
# Castellgalí
# Castellnou de Bages
# Castellnou de Seana
# Castelló de Farfanya
# Castelló d'Empúries
# Castellolí
# Castellserà
# Castellterçol
# Castellvell del Camp
# Castellví de Rosanes
# Catllar, el
# Cellera de Ter, la
# Celrà
# Centelles
# Cercs
# Cerdanyola del Vallès
# Cervelló
# Cervera
# Cervià de les Garrigues
# Cervià de Ter
# Cistella
# Ciutadilla
# Clariana de Cardener
# Cogul, el
# Colera
# Collbató
# Colldejou
# Coll de Nargó
# Collsuspina
# Colomers
# Coma, la
# Conesa
# Constantí
# Copons
# Corbera d'Ebre
# Corbera de Llobregat
# Corbins
# Corçà
# Cornellà de Llobregat
# Cornellà del Terri
# Cornudella de Montsant
# Corró d'Avall
# Creixell
# Crespià
# Cubelles
# Cubells
# Cunit
# Curullada, la
# Darnius
# Das
# Deltebre
# Dosrius
# Duesaigües
# Dusfort
# Escala, l'
# Esparreguera
# Espinelves
# Espluga Calba, l'
# Espluga de Francolí, l'
# Esplugues de Llobregat
# Espolla
# Esponellà
# Espot
# Espunyola, l'
# Estamariu
# Estany, l'
# Estaràs
# Esterri d'Àneu
# Esterri de Cardós
# Falset
# Far d'Empordà, el
# Fatarella, la
# Febró, la
# Figaró *
# Fígols
# Fígols
# Figuera, la
# Figueres
# Figuerola del Camp
# Flaçà
# Flix
# Floresta, la
# Fogars de la Selva
# Foixà
# Folgueroles
# Fondarella
# Fonollosa
# Fontanilles
# Fontcoberta
# Foradada
# Forès
# Fornells de la Selva
# Fortià
# Freginals
# Fuliola, la
# Fulleda
# Gaià
# Galera, la
# Gallifa
# Gandesa
# Garcia
# Garidells, els
# Garriga, la
# Garrigàs
# Garrigoles
# Garriguella
# Gavà
# Gavet de la Conca
# Gelida
# Ger
# Gerri de la Sal
# Gimenells
# Ginestar
# Girona
# Gironella
# Gisclareny
# Godall
# Golmés
# Gombrèn
# Gornal, la
# Gósol
# Granada, la
# Granadella, la
# Granera
# Granja d'Escarp, la
# Granollers
# Granyena de les Garrigues
# Granyena de Segarra
# Gratallops
# Gualba
# Gualta
# Gualter
# Guàrdia de Tremp
# Guardiola de Berguedà
# Guardiola de Font-rubí
# Guiamets, els
# Guils de Cerdanya
# Guimerà
# Guingueta d'Àneu, la
# Guissona
# Gurb
# Horta de Sant Joan
# Hospitalet de Llobregat, l'
# Hostalets de Balenyà, els
# Hostalets de Pierola, els
# Hostalnou de Bianya, l'
# Hostalric
# Igualada
# Isona
# Ivars de Noguera
# Ivars d'Urgell
# Ivorra
# Jafre
# Jonquera, la
# Jorba
# Juià
# Juïnyà
# Juncosa
# Juncosa del Montmell, la
# Juneda
# Lavit
# Les
# Linyola
# Llacuna, la
# Lladó *
# Lladorre
# Lladurs
# Llagosta, la
# Llagostera
# Llambilles
# Llanars
# Llançà
# Llardecans
# Llavorsí
# Lleida
# Llers
# Lles de Cerdanya
# Lliçà d'Amunt
# Lliçà de Vall
# Llimiana
# Llinars
# Llinars del Vallès
# Llívia
# Lloar, el
# Llobera
# Llorac
# Llorenç del Penedès
# Lloret de Mar
# Llosses, les
# Maçanet de Cabrenys
# Maçanet de la Selva
# Madremanya
# Maià de Montcal
# Maials
# Maldà
# Malgrat de Mar
# Malla
# Manlleu
# Manresa
# Marçà
# Margalef
# Marganell
# Martinet
# Martorell
# Martorelles
# Marzà
# Masarac
# Mas de Barberans
# Masdenverge
# Masies de Roda, les
# Masies de Voltregà, les
# Masllorenç
# Masnou, el
# Masó, la
# Maspujols
# Masquefa
# Masroig, el
# Massalcoreig
# Massanes *
# Massoteres
# Mata
# Matadepera
# Mataró
# Menàrguens
# Meranges
# Mieres
# Milà, el
# Miracle, el
# Miralcamp
# Miravet
# Moià
# Molar, el
# Molins de Rei
# Mollerussa
# Mollet del Vallès
# Mollet de Peralada
# Molló
# Molsosa, la
# Monistrol de Calders
# Monistrol de Montserrat
# Monjos, els
# Montagut
# Montblanc
# Montbrió del Camp
# Montcada
# Montclar
# Montesquiu
# Montferrer
# Montferri
# Montgai
# Montgat
# Montmajor
# Montmaneu
# Montmeló
# Montoliu de Lleida
# Montoliu de Segarra
# Montornès del Vallès
# Montornès de Segarra
# Mont-ral
# Mont-ras
# Mont-roig del Camp
# Montseny
# Móra d'Ebre
# Móra la Nova
# Morell, el
# Morera de Montsant, la
# Mosqueroles
# Múnia, la
# Muntanyola
# Mura
# Nalec
# Navarcles
# Navàs *
# Navata
# Navès
# Nou de Berguedà, la
# Nou de Gaià, la
# Noves de Segre
# Nulles
# Òdena
# Ogassa
# Olesa de Bonesvalls
# Olesa de Montserrat
# Oliana
# Oliola
# Olivella
# Olost
# Olot
# Oluges, les
# Olvan
# Omellons, els
# Omells de na Gaia, els
# Ordis
# Organyà
# Oristà
# Òrrius
# Os de Balaguer
# Osor
# Ossó de Sió
# Pacs del Penedès
# Palafolls
# Palafrugell
# Palamós
# Palau d'Anglesola, el
# Palau-sator
# Palau-saverdera
# Palau-solità i Plegamans
# Pallaresos, els
# Pallargues, les
# Pallejà
# Palma d'Ebre, la
# Palma de Cervelló, la
# Palol de Revardit
# Pals
# Papiol, el
# Pardines
# Parets del Vallès
# Parlavà
# Passanant
# Pau
# Paüls
# Penelles
# Pera, la
# Perafita
# Perafort
# Peralada
# Peramola
# Perelló, el
# Pi de Sant Just, el
# Piera
# Piles, les
# Pineda de Mar
# Pinell de Brai, el
# Pinós
# Pira
# Pla del Penedès, el
# Pla de Santa Maria, el
# Pla de Sant Tirs, el
# Planes d'Hostoles, les
# Planoles
# Platja d'Aro
# Poal, el
# Pobla de Cérvoles, la
# Pobla de Claramunt, la
# Pobla de Lillet, la
# Pobla de Mafumet, la
# Pobla de Massaluca, la
# Pobla de Montornès, la
# Pobla de Segur, la
# Poboleda
# Polinyà
# Pont d'Armentera, el
# Pont de Bar, el
# Pont de Claverol, el
# Pont de Molins
# Pont de Suert, el
# Pont de Vilomara, el
# Pontils
# Pontons
# Pontós
# Ponts
# Porrera
# Portbou
# Port de la Selva, el
# Portella, la
# Pradell de la Teixeta
# Prades
# Prat de Comte
# Prat de Llobregat, el
# Pratdip
# Prats
# Prats de Lluçanès
# Prats de Rei, els
# Preixana
# Preixens
# Premià de Dalt
# Premià de Mar
# Preses, les
# Prullans
# Puigcerdà
# Puigdàlber
# Puiggròs
# Puigpelat
# Puig-reig
# Puigverd d'Agramunt
# Puigverd de Lleida
# Pujalt
# Quar, la
# Quart
# Queralbs
# Querol
# Rabós
# Rajadell
# Rasquera
# Regencós
# Rellinars
# Renau
# Reus
# Rialp *
# Riba, la
# Riba-roja d'Ebre
# Ribera de Cardós
# Ribes de Freser
# Riera de Gaià, la
# Ripoll
# Ripollet
# Riudarenes
# Riudaura
# Riudecanyes
# Riu de Cerdanya
# Riudecols
# Riudellots de la Selva
# Riudoms
# Riumors
# Roca del Vallès, la
# Rocafort de Queralt
# Roda de Barà *
# Roda de Ter
# Rodonyà
# Roquetes
# Roses
# Rosselló
# Rourell, el
# Rubí
# Rubió
# Rupià
# Rupit
# Sabadell
# Sagàs
# Sagrera, la
# Salardú
# Salàs de Pallars
# Saldes
# Sales de Llierca
# Sallent
# Salomó
# Salou
# Salt
# Salvà, Can
# Sanaüja
# Santa Bàrbara
# Santa Cecília de Voltregà
# Santa Coloma de Cervelló
# Santa Coloma de Farners
# Santa Coloma de Gramenet
# Santa Coloma de Queralt
# Santa Cristina d'Aro
# Sant Adrià de Besòs
# Santa Eugènia de Berga
# Santa Eulàlia
# Santa Eulàlia de Puig-oriol
# Santa Eulàlia de Riuprimer
# Santa Fe del Penedès
# Sant Agustí de Lluçanès
# Santa Llogaia d'Àlguema
# Santa Margarida de Montbui
# Santa Maria de Besora
# Santa Maria de Corcó
# Santa Maria de Martorelles
# Santa Maria de Merlès
# Santa Maria de Miralles
# Santa Maria de Palautordera
# Santa Maria d'Oló
# Sant Andreu de la Barca
# Sant Andreu de Llavaneres
# Sant Andreu Salou
# Sant Antolí i Vilanova
# Sant Antoni de Vilamajor
# Santa Oliva
# Santa Pau
# Santa Perpètua de Mogoda
# Santa Susanna
# Sant Bartomeu del Grau
# Sant Boi de Llobregat
# Sant Boi de Lluçanès
# Sant Carles de la Ràpita
# Sant Cebrià de Vallalta
# Sant Celoni
# Sant Climenç
# Sant Climent de Llobregat
# Sant Climent Sescebes
# Sant Cugat del Vallès
# Sant Cugat Sesgarrigues
# Santes Creus
# Sant Esteve de la Sarga
# Sant Esteve de Llémena
# Sant Esteve d'en Bas
# Sant Esteve de Palautordera
# Sant Esteve Sesrovires
# Sant Feliu de Buixalleu
# Sant Feliu de Codines
# Sant Feliu de Guíxols
# Sant Feliu de Llobregat
# Sant Feliu de Pallerols
# Sant Feliu Sasserra
# Sant Fost de Campsentelles
# Sant Fruitós de Bages
# Sant Gregori
# Sant Guim de Freixenet
# Sant Guim de la Plana
# Sant Hilari Sacalm
# Sant Hipòlit de Voltregà
# Sant Iscle de Vallalta
# Sant Jaume de Frontanyà
# Sant Jaume de Llierca
# Sant Jaume dels Domenys
# Sant Jaume d'Enveja
# Sant Joan de les Abadesses
# Sant Joan de Mediona
# Sant Joan de Mollet
# Sant Joan Despí
# Sant Joan de Vilatorrada
# Sant Joan les Fonts
# Sant Jordi Desvalls
# Sant Julià de Cerdanyola
# Sant Julià de Ramis
# Sant Julià de Vilatorta
# Sant Just Desvern
# Sant Llorenç de la Muga
# Sant Llorenç de Morunys
# Sant Llorenç d'Hortons
# Sant Llorenç Savall
# Sant Martí d'Albars
# Sant Martí de Llémena
# Sant Martí de Maldà
# Sant Martí de Tous
# Sant Martí Sacalm
# Sant Martí Sarroca
# Sant Martí Sesgueioles
# Sant Martí Vell
# Sant Mateu de Bages
# Sant Miquel de Campmajor
# Sant Miquel de Fluvià
# Sant Miquel d'Olèrdola
# Sant Mori
# Sant Pau de Segúries
# Sant Pau d'Ordal
# Santpedor
# Sant Pere de Ribes
# Sant Pere de Riudebitlles
# Sant Pere de Torelló
# Sant Pere de Vilamajor
# Sant Pere Pescador
# Sant Pere Sallavinera
# Sant Pol de Mar
# Sant Quintí de Mediona
# Sant Quirze de Besora
# Sant Quirze del Vallès
# Sant Quirze Safaja
# Sant Ramon
# Sant Sadurní d'Anoia
# Sant Sadurní de l'Heura
# Sant Sadurní d'Osormort
# Sant Salvador de Guardiola
# Sant Vicenç de Castellet
# Sant Vicenç dels Horts
# Sant Vicenç de Montalt
# Sant Vicenç de Torelló
# Sarral
# Sarrià de Ter
# Sarroca de Bellera
# Sarroca de Lleida
# Savallà del Comtat
# Secuita, la
# Selva del Camp, la
# Selva de Mar, la
# Senan
# Sénia, la
# Senterada
# Sentiu de Sió, la
# Sentmenat
# Serinyà
# Seròs
# Serra de Daró
# Serrateix
# Setcases
# Seu d'Urgell, la
# Seva
# Sidamon
# Sils
# Sitges
# Siurana
# Sobremunt
# Soleràs, el
# Solivella
# Solsona
# Sora
# Sorribes de la Vansa
# Sort
# Soses
# Sudanell
# Sunyer
# Súria
# Tagamanent
# Talamanca
# Talarn
# Talavera
# Tallada d'Empordà, la
# Taradell
# Tarragona
# Tàrrega
# Tarrés
# Tarroja de Segarra
# Tavèrnoles
# Tavertet
# Teià
# Térmens
# Terrades
# Terrassa
# Tiana
# Tírvia
# Tiurana
# Tivenys
# Tivissa
# Tona
# Torà
# Tordera
# Torelló
# Torms, els
# Tornabous
# Torrebesses
# Torre de Cabdella, la
# Torre de Claramunt, la
# Torre de Fontaubella, la
# Torre de l'Espanyol, la
# Torredembarra
# Torrefarrera
# Torrefeta
# Torregrossa
# Torrelameu
# Torrelles de Foix
# Torrelles de Llobregat
# Torrent
# Torres de Segre
# Torre-serona
# Torroella de Fluvià
# Torroella de Montgrí
# Torroja del Priorat
# Tortellà
# Tortosa
# Toses
# Tossa de Mar
# Tremp
# Tuixent *
# Ullà
# Ullastrell
# Ullastret
# Ulldecona
# Ulldemolins
# Ultramort
# Urús
# Vacarisses
# Vajol, la
# València d'Àneu
# Vallbona d'Anoia
# Vallbona de les Monges
# Vallcebre
# Vallclara
# Vallfogona de Balaguer
# Vallfogona de Ripollès
# Vallfogona de Riucorb
# Vallgorguina
# Vallirana
# Vall-llobrega
# Vallmoll
# Vallromanes
# Valls
# Valls
# Vandellòs
# Veciana
# Vendrell, el
# Ventalló
# Verdú
# Verges
# Vespella de Gaià
# Vic
# Vidrà
# Vidreres
# Vielha
# Vilabella
# Vilabertran
# Vilablareix
# Vilada
# Viladamat
# Viladasens
# Viladecans
# Viladecavalls
# Vilademuls
# Viladrau
# Vilafant
# Vilafranca del Penedès
# Vilagrassa
# Vilajuïga
# Vilalba dels Arcs
# Vilalba Sasserra
# Vilaller
# Vilallonga del Camp
# Vilallonga de Ter
# Vilamacolum
# Vilamalla
# Vilamaniscle
# Vilamòs
# Vilamur
# Vilanant
# Vilanova de Bellpuig
# Vilanova de la Barca
# Vilanova de l'Aguda
# Vilanova del Camí
# Vilanova del Vallès
# Vilanova de Meià
# Vilanova de Prades
# Vilanova de Sau
# Vilanova d'Escornalbou
# Vilanova de Segrià
# Vilanova i la Geltrú
# Vilaplana
# Vilar d'Urtx, el
# Vila-rodona
# Vila-sacra
# Vila-sana
# Vila-seca
# Vilassar de Dalt
# Vilassar de Mar
# Vilaür
# Vilaverd
# Vilella Alta, la
# Vilella Baixa, la
# Vilobí del Penedès
# Vilobí d'Onyar
# Vilopriu
# Vilosell, el
# Vimbodí
# Vinaixa
# Vinebre
# Vinyols
# Vulpellac
# Xerta

# %% [markdown]
# ## Types of elements in the database
#
# The main elements that can be found among other less important are the following:
#
# Abbreviature | Meaning
# ---    |   ---
# 'cap'  | Cap de municipi
# 'barri'| Barri, sector urbà (+50.000 hab.)
# 'nucli'| Nucli de població (poble, llogaret...)
# 'diss.'| Veïnat disseminat
# 'e.m.d.'| Entitat municipal descentralitzada
# mun. | Nom del municipi quan aquest no coincideix amb la capital
# edif. | Edificació aïllada
# edif. hist. | Edifici històric (ermita, església, castell...)

# %%
db.ciutats.count()
# Out:
# 52698

# %% [markdown]
# # 2. Add to the database some important international cities

# %% [markdown]
# To achieve this objective, I will be using SPARQL language, that let obtain information from for example DBPEDIA, a database containing information extracted from the WIKIPEDIA.

# %%
import json
from SPARQLWrapper import SPARQLWrapper, JSON
 
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setReturnFormat(JSON)
 
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX yago: <http://dbpedia.org/class/yago/>
PREFIX dbpedia-owl: <http://dbpedia.org/ontology/>
 
SELECT ?title ?geolat ?geolong
    WHERE {
        #?place rdf:type <http://dbpedia.org/ontology/Place> .
        #?place dbpedia-owl:country <http://dbpedia.org/resource/Spain> .
        # ?place foaf:name ?title .
        # ?place geo:lat ?geolat .
        # ?place geo:long ?geolong .
        #FILTER ((?geolong > 0.5 && ?geolong < 2.7) && (?geolat < 42.5 && ?geolat > 40.5))
        #FILTER (LANG(?title)='ca')
    }
""")
results = sparql.query().convert()
print results
# Out:
# {u'head': {u'link': [], u'vars': [u'title', u'geolat', u'geolong']}, u'results': {u'distinct': False, u'bindings': [], u'ordered': True}}

# %% [markdown]
# # 2.- Create a database of news

# %% [markdown]
# In order to create a database that will contain news from a few digital news sites from Catalonia, I will be fetching the information from their RSS publications. I will get the <strong>title</strong>, the <strong>description</strong>, the <strong>date of publication</strong> and the <strong>name of the news site</strong>.

# %%
import feedparser
from bs4 import BeautifulSoup
from time import mktime
import time
from datetime import datetime

def get_db_news():
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client.noticies
    return db

def add_news(db, diari, data, titol, desc):
    db.noticies.insert({"diari":diari, "data":data, "titol":titol, "descripcio":desc})  

def get_news(diari,web, today=False):
    db = get_db_news()
    rss = web
    feed = feedparser.parse(rss)
    print len(feed["entries"])
    vals = []
    for key in feed["entries"]: 
        title = BeautifulSoup(key["title"]).get_text()
        date = datetime.fromtimestamp(mktime(key["published_parsed"]))
        #print date
        date_formated = date.strftime("%d/%m/%Y")
        if today and date_formated != time.strftime("%d/%m/%Y"):
            print date_formated
            continue
        if db.noticies.find({"titol":title}).count() > 0:
            continue
        #desc_formated = BeautifulSoup(unidecode.unidecode(key["description"])).get_text()
        desc_formated = BeautifulSoup(key["description"]).get_text()
        #print desc_formated.get_text()
        ret_val = [date_formated,title,desc_formated]
        #print ret_val
        add_news(db,diari,date,title,desc_formated)
        vals.append(ret_val)
    return vals

import os

def get_news_job():
    print "******* Running process:", os.getpid()
    get_news('ara','http://www.ara.cat/rss/')
    get_news('regio7','http://www.regio7.cat/elementosInt/rss/1')
    get_news('vilaweb','http://www.vilaweb.cat/rss/')
    db = get_db_news()
    print db.noticies.find().count()
    print "******* Process ended!"

# %%
get_news_job()
# Out:
# *******Running process: 13376
# 70
# 16
# 21
# 1491
# *******Process ended!

# %% [markdown]
# #3.- Identify cities in a text

# %% [markdown]
# First, I create a train database to check results

# %%
db = get_db_news()
noticies = db.noticies.find()
#db.create_collection('train_set')
i = 1
array_noticies = []
for noticia in noticies:
    if i>100:
        continue
    array_noticies.append([noticia['diari'],noticia['data'],noticia['titol'],noticia['descripcio'],"None"])
    i += 1
# add a field that will contain the location of the text
print len(array_noticies)
for i in range (11,100):
    print array_noticies[i][3]
    array_noticies[i][4] = raw_input()
# Out:
# 100
# Aquest diumenge l'ARA dedica el dossier a l'Europa de després de Hitler. El líder nazi es va suïcidar el 30 d'abril disparant-se un tret a la templa. El seu cos i el de la seva dona, Eva Braun (s'havien casat el dia anterior), van ser incinerats. El reportatge abordarà els efectes del conflicte bèl·lic sobre Europa i com va ser l'endemà en un continent devastat que va haver de reconstruir-se. Detallarem com mesos després van continuar els assassinats de jueus, les matances contra minories ètniques, la venjança contra els col·laboracionistes... Com els camins d'una Europa sense transports, amb cultius i ciutats arrasades, es van omplir de milions de desplaçats. I què va passar a Espanya, un país en plena dictadura. A més, tot el diari estarà 'tunejat' amb frases de testimonis, escriptors, historiadors i altres fonts sobre l'Europa de postguerra.Diumenge mateix començarà la promoció dels cartells de la Segona Guerra Mundial, una selecció feta pel diari que començarà amb l’emblemàtic 'We can do it!', que s’encartarà a l’ARA i es podrà aconseguir de forma gratuïta aquell diumenge. La tria continuarà (per 0,50 cèntims) amb exemples tan representatius com el de 'París se libère', cartell anònim de la resistència comunista editat pel diari 'L’avant-garde' el 1944; 'Keep calm and carry on', lema del govern britànic per alçar la moral dels ciutadans en cas d’una hipotètica invasió nazi, o 'I want you for the U.S. Army', una crida a allistar-se a l’exèrcit dels Estats Units.Llibre a la venda En la col·lecció d'obres d'art sobre Hitler no poden faltar-hi les comèdies, com per exemple la versió del llibre de Timur Vermes 'Ha tornat', que encara no s'ha pogut veure als cines i mostrarà un Hitler que desperta en el Berlín actual. Aquest llibre es pot aconseguir aquest cap de setmana amb l'ARA (a un preu de 8,95 euros).
# Berlín
# Els partidaris de seguir formant part d'Espanya s'imposarien en un referèndum als partidaris de la independència si avui se celebrés un referèndum, segons un sondeig de 'La Vanguardia'. Així, l'enquesta, que ha fet l'empresa Feedback, detecta que el 47,9% de l'electorat votaria 'no', davant el 43,7% que votaria 'sí'. L'enquesta apunta que hi hauria un 8,3% d'indecisos que podrien arribar a decantar el resultat.Segons el sondeig, el 24,4% dels enquestats estaria a favor de continuar amb el procés d'independència per la via unilateral si els partidaris de la secessió obtinguessin només la meitat més un dels diputats de la cambra catalana (els 68 de la majoria absoluta) sense que arribessin a la meitat dels vots.
# None
# LA PORTADA EN PDFRere el misteri de Christa Leem. Un llibre-objecte amb 10 fotografies de Josep Gol recorda l’artista del nu que va fascinar la intel·lectualitat de la Barcelona dels 70.També trobareu a l'ARA Diumenge:Entrevista de Carles Capdevila a Xavier Pastor, un dels referents de l’ecologisme a Espanya. Com a biòleg marí va treballar més de deu anys a l‘Institut Espanyol d’Oceanografia i s’ha especialitzat en l’anàlisi dels estocs pesquers. Com a activista va iniciar-se al GOB (Grup d’Ornitologia Balear).La tragèdia infantil rere el viral més famós. Osman Sagirili explica com va fer la fotografia de la Hudea, una nena refugiada siriana de quatre anys que es va rendir, aterrida, davant la seva càmera.Aus i 'drones', una convivència sense normes. Les aus i els ‘drones’ han de compartir espai. Els científics demanen regulacions perquè els ocells no s’espantin i s’allunyin dels seus espais naturals o fins i tot morin en xocar.El secret del càncer més resistent. Joan Massagué troba el mecanisme pel qual les cèl·lules cancerígenes es tornen resistents als fàrmacs, una fita que obre camí a nous tractaments.
# Barcelona
# La torbadora Juliet de 'Criatures celestials' (1994), la càndida Marianne de 'Sentit i Sensibilitat' (1995), la decidida Rose de 'Titanic' (1997) o l'enigmàtica Hanna d''El lector' (2008). Alguns dels millors personatges cinematogràfics femenins dels últims 20 anys tenen les faccions de Kate Winslet. L'actriu britànica protagonitza aquest diumenge un RAR tan heterogeni com les dones que ha interpretat al llarg de la seva carrera.Malgrat haver sigut nominada en sis ocasions, Kate Winslet només ha guanyat un Oscar. Va ser el 2008 pel seu paper a 'El lector'. Al film, un adolescent i una misteriosa revisora de tramvia al Berlín dels anys 50 coincideixen per atzar i inicien una sèrie de trobades sexuals. Ella descobrirà un gran plaer en les emocions que li transmeten les pàgines dels llibres que el jove Michael li llegeix en veu alta. Entre aquestes lectures, la de La dama del gosset, de Txékhov. A partir d'aquest lligam la revista es trasllada a Taganrog, la desconeguda ciutat russa on va néixer l'autor, i ens descobreix la seva història i vida actual.A més, el RAR repassa el llistat d'actrius que, com Kate Winslet, s'han negat a modificar el seu físic amb l'ajuda de la cirurgia i explora la potència lírica de tenors tan irresistibles com Mario Lanza, la veu que enamorava la Juliet de Criatures Celestials. Per últim, Steve Jobs (2015), l'última pel·lícula que ha rodat Winslet, és l'excusa perfecta perquè la revista expliqui la història de NeXt, l'aventura empresarial que va dirigir Steve Jobs als anys 80 després de ser acomiadat per Apple.
# Berlín
# “És obvi que l’AVE és meravellós, i a tots ens agrada viatjar-hi, però també era meravellós anar a Nova York amb el Concorde [un avió supersònic que va deixar de volar el 2003], però la qüestió és si és una inversió viable i rendible. La nostra idea és que les línies que ja hi ha fetes s’hauran d’optimitzar, però que qualsevol inversió futura [hi ha 1.
# Nova York
# José Carlos Díez: “Per l’aeroport de Castelló no posem en dubte tota la xarxa”José Carlos Díez va manifestar la seva alarma quan des de Ciutadans es va fer la promesa electoral d’aturar les línies d’AVE en construcció. Aquest professor d’economia de la Universidad de Alcalá creu que no s’ha de mesurar la rendibilitat d’una inversió pública en termes comptables, perquè, “si no, gairebé cap infraestructura seria possible”.
# Castelló
# Aquest any vaig encapçalar el meu article a l’ARA previ al Mobile World Congress pronosticant que WhatsApp aprofitaria l’ocasió per incorporar les trucades de veu a la seva aplicació mòbil. Em vaig precipitar: encara van trigar unes setmanes a fer-ho. Els usuaris d’Android i els de BlackBerry tenim la funció disponible des de fa un mes i als d’iPhone els l’acaben d’activar, i per això en deveu haver sentit parlar aquests dies: la majoria dels “líders d’opinió” fan servir el mòbil d’Apple i tot just han descobert la novetat.
# None
# L'exdirigent de la Crida i actual adjunt al Síndic de Greuges, Jordi Sànchez, ha formalitzat aquest divendres la seva candidatura al secretariat nacional de l'ANC, segons han confirmat a l'ARA fonts de l'entitat. D'aquesta manera, és el candidat més ben situat per esdevenir el relleu de Carme Forcadell al capdavant de l'Assemblea, tal com va avançar l'ARA. El llistat provisional dels candidats el donarà a conèixer aquest dissabte l'entitat als seus associats.Ara seran les bases de l'entitat les que escolliran els integrants del nou secretariat nacional en una jornada electoral el 9 de maig. El secretariat l'integren 75 persones, de les quals 50 seran escollides per les assemblees territorials i 25 seran representants nacionals. Seran precisament els escollits per al secretariat els que, en la reunió constituent de la nova direcció del 16 de maig, triaran d'entre els seus membres el nou president.Té el suport d’amplis sectors de la cúpula de l’organització independentista, cosa que el fa el candidat més ben situat, sense perdre de vista que, com que es tracta d’una entitat assembleària, el resultat de l’operació esdevé imprevisible pel sistema de votació.Activista pròxim a ICVVinculat durant anys a ICV, amplis sectors de l'entitat veuen en Sànchez el perfil que pot ajudar a imprimir un caràcter més social a l'Assemblea en el camí cap a les eleccions plebiscitàries del 27-S i amb l'objectiu de sumar al màxim de capes socials  al projecte independentista. També opten a integrar la nova direcció de l'ANC l'exdirector del Museu d'Història de Catalunya Agustí Alcoberro, o l'editor i director del Born Centre Cultural, Quim Torra, entre altres noms de diferents sensibilitats socials i polítiques.
# None
# Els diaris d'avui, dissabte, titulen:El Mundo: "El sector més radical demana la refundació de Podem"La Razón: "Monedero va dimitir perquè Iglesias va tombar el seu programa electoral"El Periódico: "El Nepal posa a prova la solidaritat mundial"La Vanguardia: "El no a la independència supera el sí per 4 punts"El País: "El PP continua primer a Madrid i augmenta el seu avantatge en l'alcaldia"El Punt Avui: "El to sindical puja per reivindicar salaris més alts"Abc: "Primer de Maig pobre en idees i participació"ARA: "L'AVE entra en campanya"
# Madrid
# “A Qatar no hi ha esclavatge i es respecten tots els drets”. Aquesta cita d’un treballador jordà titula un reportatge de l’esportiu  As sobre les condicions laborals al país que organitzarà el Mundial de futbol del 2022. “No hem tingut cap problema, més enllà d’alguna discussió per les màquines del gimnàs, que són poques per a tants”, diu un altre dels entrevistats, responsable de vetllar pel presumpte bon compliment de les obres i a qui imagino amb bona musculatura, sobretot a la part de les galtes.
# Qatar
# El PSOE d'Andalusia ha acceptat el pacte anticorrupció proposat per Ciutadans Andalusia, amb la qual cosa s'obre "un espai de diàleg en què Ciutadans plantejarà les seves propostes i projectes", però "no per parlar de govern ".Així ho indica Ciutadans en un comunicat, segons el qual el PSOE andalús assumeix els 10 punts del decàleg del partit liderat per Juan Marín.La signatura del pacte, recorda Ciutadans, "era la condició imprescindible per obrir aquest procés, però no per parlar de govern, ja que Ciutadans no entrarà en un govern que no presideixi ni hi ocuparà càrrecs".Segons Ciutadans, el diàleg que s'obrirà serà "sobre acords puntuals que afectin reactivació econòmica, polítiques socials, sanitat, educació i regeneració democràtica, entre els principals assumptes"Ciutadans mantindrà aquest dissabte al matí una reunió amb el PSOE per parlar sobre aquestes qüestions i d'altres relacionades amb el programa electoral.Juan Marín, segons el comunicat, ja ha avançat que "de moment" no ha canviat la posició de Ciutadans respecte del vot negatiu que tenen previst per a la investidura de la candidata a la presidència de la Junta, prevista per a la setmana que ve.
# Andalusia
# El fins dijous número tres de Podem, Juan Carlos Monedero, no pensa desaparèixer de l’escena política. Malgrat la dimissió com a secretari de procés constituent i de programa, Monedero va advertir ahir que la sortida de la cúpula orgànica de Podem respon a l’“única intenció” d’“empènyer amb més força”. Ara des de fora, “sense els frens dels òrgans col·legiats, sense les penúries de les organitzacions”, i “sense el dogal de les urgències electorals” i la “metzina dels mitjans i els seus embolics que envileixen”.
# None
# Quan Anna Ponces i la seva parella, l’Alba, van decidir que volien ser mares, van acudir a la sanitat pública, i tot i que d’entrada es van trobar amb moltes negatives per accedir a les tècniques de reproducció assistida, finalment, després d’un llarg periple, van aconseguir arribar fins a l’Hospital del Mar, on a l’Anna li van practicar dues inseminacions que no van prosperar.
# Hospital del Mar
# Sis dies després del terratrèmol del Nepal, la barcelonina Roser Palau, que havia anat a fer tresc al parc natural del Langtang, segueix desapareguda. Segons la informació de què disposa per ara la Generalitat, és l'única catalana que encara no s'ha trobat, després que dues persones tornessin sanes i estàlvies aquesta setmana. La mare de Palau, Teresa Pareta, ha denunciat en declaracions a l'ACN la ineficàcia i la desorganització de l'ambaixada espanyola a Nova Delhi i la falta d'informació per part del ministeri d'Afers Exteriors. Pareta considera que l'executiu espanyol "no fa prou" per trobar els desapareguts i a més "no es preocupa de dir res" als familiars.Roser Palau, de 37 anys, va marxar el dia 21 des de Shyabru Besi cap al parc natural de Langtang, on volia fer un trekking. En un país on les comunicacions ja no eren fàcils abans del terratrèmol, la seva família va parlar amb ella el dia 20 per últim cop. El dissabte 25 un tremolor de 7,8 graus en l'escala de Richter es cobrava més de 6.000 vides i deixava milers de desapareguts. Des d'aleshores la seva família ha intentat contactar amb ella per tots els mitjans però sense èxit.Durant aquests dies, Pareta ha estat trucant "dos o tres cops al dia" des de la seva residència de Premià de Mar a l'ambaixada de Nova Delhi, que és la que se n'encarrega, ja que a Kàtmandu no hi ha ambaixada espanyola. Denuncia que la majoria de vegades no es posen al telèfon i, quan ho fan, "segons qui contesta és penós" perquè els ha de tornar a explicar una vegada i una altra la història de la seva filla. La mare de Palau lamenta la desorganització i té la sensació que "a l'ambaixada cadascú té una llista diferent" de persones."El govern no fa prou" i no investiga amb diligència per trobar els desapareguts, recrimina Parera, qui és especialment crítica amb el ministre d'Afers Exteriors, José Manuel García-Margallo: "Va dir que no marxaria fins que l'últim espanyol no fos trobat. El dia següent va marxar. Ja sé que no va anar allà per ells, però ja que va dir una cosa així, com a mínim que ho faci i si no que hi deixi algú delegat i que ho digui, perquè al govern ningú es preocupa de dir res".Palau és originària de Barcelona però ha viscut algunes temporades en diversos països de l'estranger. Des del setembre és al Sud-est Asiàtic i en principi té previst tornar a Barcelona al maig.Poc després del terratrèmol, la secretaria general de l'Esport va posar-se en contacte amb diversos aficionats a la muntanya que eren al Nepal. Un cop fetes les investigacions pertinents, en un primer moment la secretaria d'Afers Exteriors de la Generalitat va detectar dos catalans més que estaven desapareguts però finalment van ser trobats i van tornar amb un dels avions que van aterrar aquesta setmana a Madrid, tal com han afirmat fonts del Govern a l'ACN. La Generalitat no té competències consulars però la secretaria d'Afers Exteriors manté el contacte amb l'ambaixador espanyol a Nova Delhi i amb els serveis consulars espanyols per tenir informació de primera mà sobre la catalana que encara segueix desapareguda.Segons dades del ministeri d'Afers Exteriors, encara hi ha 78 espanyols desapareguts al Nepal. Es creu que la immensa majoria no han pogut contactar amb les seves famílies o amb les autoritats a causa del caos en què està sumit el país després del terratrèmol.
# Premià de Mar
# El titular del jutjat número 3 de Reus ha deixat aquest divendres en llibertat amb càrrecs la primera tinent d'alcalde de l'Ajuntament de Reus, Teresa Gomis, detinguda fa tres dies pel cas Innova. El magistrat li imputa delictes societaris, falsedat documental, contra l'administració pública, blanqueig de capitals i contra la salut pública. La interlocutòria del jutge posa de manifest que dos imputats han afirmat que Gomis pressionava per "aconseguir més facturació per a l'empresa Traiber", que va arribar a vendre pròtesis en mal estat a l'Hospital Sant Joan. Com a mesures cautelars se li ha retirat el passaport i haurà de comparèixer cada dilluns al jutjat. Gomis ha declarat durant unes tres hores.
# Reus
# A la vall de Nashika, al districte nepalès de Kavre, no han sentit a parlar ni d’ONGs, ni d’ajuda internacional, ni de cap indemnització del govern. Per a molts, fins i tot, és el primer cop que veuen un occidental. En aquesta àrea remota, 50 quilòmetres a l’oest de Kàtmandu, els supervivents del terratrèmol estan tirant endavant ells sols. Les vistes són impressionants: envoltats de turons verds, s’entreveu l’Himàlaia al fons, quan el dia és clar.
# Kàtmandu
# Suki Kim va néixer a Corea del Sud i des dels 13 anys viu als Estats Units. Publica  Sin ti no hay nosotros (Blackie Books), en què relata els seus mesos infiltrada a Corea del Nord com a professora d’anglès en una universitat per a l’elit del país, portada per uns missioners a Pyongyang. Descriu en primera persona escenes esgarrifoses i asfixiants de com es manipula els joves i com se’ls menteix sistemàticament.
# Pyongyang
# “És molt difícil, molt dur. Jo diria que això no és viure. Simplement, sobrevivim”. Per a l’Olga, una infermera jubilada, el dia a dia és cada vegada més difícil a la ciutat de Donetsk. Va cobrar la seva última pensió el juliol de l’any passat i, des de llavors, sobreviu gràcies a l’ajut dels veïns i d’una organització humànitaria que li proporciona queviures un cop al mes.
# Donetsk
# Carles Capdevila entrevista a Xavier Pastor, vicepresident d'Oceana.
# None
#
# None
# La Fiscalia de l'estat nord-americà de Maryland ha anunciat aquest divendres que presentarà càrrecs per possible homicidi contra sis agents de la Policia de Baltimore per la mort del jove negre Freddie Gray, després de revisar els resultats de diverses investigacions.En una roda de premsa a Baltimore, la fiscal Marilyn Mosby ha assegurat que Gray va ser arrestat "il·legalment" i que formularà càrrecs pel possible homicidi del jove de 25 anys, que no va cometre cap delicte.Un dels sis agents ha estat acusat d'assassinat en segon grau (el càrrec més greu), mentre que dos més s'enfronten a càrrecs d'homicidi involuntari i la resta haurà de respondre per assalt i incompliment del deure.Una setmana en coma i una onada de protestesFreddie Gray va morir el passat 19 d'abril, després d'una setmana en coma per una lesió de columna provocada durant el seu arrest una setmana abans.La mort de Gray va desencadenar una onada de protestes a Baltimore que el dia del seu funeral, dilluns passat, van acabar en greus disturbis per tota la ciutat, la declaració de l'estat d'emergència, la imposició d'un toc de queda des de dimarts i centenars de detencions.
# Baltimore
# El caos ha regnat aquesta tarda al centre de Milà, convertit en una batalla campal entre activistes antisistema i la policia, després d'una manifestació pacífica contra l'Exposició Universal, que ha provocat importants danys materials.Tot ha començat després que aquesta ciutat italiana, que des d’aquest divendres organitza l'Exposició Universal, acollís una manifestació sota el lema 'Expo: deute, ciment i precarietat', que ha transcorregut pacíficament.Però a la cua de la marxa hi havia diverses desenes d'encaputxats a l'estil del conegut com a 'Bloc Negre', una forma de reivindicació violenta sorgida a finals de la dècada de 1980 i d'ideologia anticapitalista.Quan la manifestació ha arribat a la via Carducci s'ha desencadenat tot, ja que els antisistema han començat a llançar pedres, ampolles, petards i tot tipus d'objectes als centenars de policies antiavalots que els seguien.Els agents en un primer moment han respost llançant aigua a pressió, però, quan s'han intensificat els atacs contra ells, han optat pels gasos lacrimògens.Destrosses de tota menaMilà s'ha convertit així en un improvisat camp de batalla en què els antisistema, pel que sembla dividits en grups, han provocat tota mena de destrosses als carrers de les zones del centre i el nord de la ciutat.Les televisions han difós imatges de jardineres i contenidors bolcats, murs pintats amb símbols anarquistes, finestres i aparadors rebentats i diversos cotxes en flames, apagades ràpidament pel cos de Bombers.Els enfrontaments han durat poc més d'una hora i mitja i, quan han acabat, un dels carrers ha quedat cobert per una infinitat de peces de vestir negres, que els antisistema han abandonat per passar desapercebuts i escapar.A més també hi havia les improvisades armes que han fet servir durant els enfrontaments, com escuts, pics casolans o còctels Molotov.Pel que fa al nombre de detencions, la Prefectura de Policia de Milà encara no n'ha especificat el nombre.Tensió en augmentLa tensió ha anat en augment durant les últimes hores, ja que les autoritats comptaven amb la presència d'aquests grups violents.Per aquesta raó, el ministeri de l'Interior italià havia anunciat una ampliació de les mesures de seguretat a la capital llombarda.
# Milà
# La campanya electoral està certificant la fragmentació del sistema de partits britànic, tradicionalment dominat per laboristes i conservadors. Ja es va produir en les últimes eleccions, quan cap partit va treure majoria, i les enquestes apunten que es repetirà aquest 7 de maig.
#  Les enquestes indiquen que guanyaran conservadors o laboristes però que el guanyador no podrà governar en solitari.
# None
# Aquest diumenge, a l'ARA, Antoni Bassas entrevista al metge i investigador Bonaventura Clotet. Clotet i el seu equip han desenvolupat un joc per mòbils intel·ligents que els ajudarà a aconseguir ingressos que destinaran a la investigació de la malaltia. El podeu descarregar aquí.
# None
# El 2014, ja encarant el tram final del mandat, l’Ajuntament de Barcelona va desplegar les grans obres previstes a la ciutat. Grans canvis com la remodelació del passeig de Gràcia, del carrer Balmes, del Paral·lel i la que ha comportat més polèmica: la de la Diagonal. Són alguns dels projectes insígnia. Les característiques de totes aquestes actuacions són les mateixes: reduir les calçades i ampliar les voreres.
# Barcelona
# El Poble-sec, aquest barri sovint oblidat del qual només sentim parlar quan se cita el seu fill més il·lustre, Joan Manuel Serrat, o quan sona alguna de les cançons de La Salseta. És el que té viure a l’altra banda del Paral·lel, a la falda de Montjuïc, on tots els carrers fan pujada i on trobar un turista és poc probable. Però els carrers que fan pujada a vegades amaguen sorpreses.
# Poble-sec
# Una ciutat on es puguin moure amb seguretat, tranquil·litat i normalitat: aquesta és la reivindicació que els col·lectius de cecs fan al govern de Barcelona resultant de les eleccions municipals del 24 de maig. Aprofitant que els comicis són a tocar i que els polítics estan més oberts a escoltar que mai, l’Associació Catalana per a la Integració del Cec (ACIC) i l’Assemblea per la Diversitat (AxD) dimarts van organitzar un debat amb les formacions polítiques per posar sobre la taula les propostes que consideren irrenunciables per poder tenir una vida normalitzada a la ciutat.
# Barcelona
# “Mani qui mani, nosaltres sempre hem d’estar picant. Segons qui mani, potser hem de picar quatre cops o vuit, però no podem deixar de picar”. La frase és de la mare de la Custodia Moreno, i ella se l’ha aplicat tota la vida. Tant quan lluitava per aconseguir unes condicions de vida dignes per a les persones que com ella i la seva família vivien a les barraques, com en totes i cadascuna de les batalles veïnals que ha ajudat a guanyar al seu barri, el Carmel.
# el Carmel
# Desenes de fotografies en blanc i negre omplen les parets del Pou de la Figuera -o el forat de la vergonya -. Situades en un dels llocs més emblemàtics de Sant Pere i Santa Caterina, les imatges són un reflex de la realitat intergeneracional i multicultural del barri. Els forasters se les miren encuriosits. En canvi, els del barri les observen amb orgull i s’assenyalen els uns als altres quan es reconeixen a les parets.
# Pou de la Figuera
# Els 13 tipus de llet i vinils dels 70Tàber Cafè ha sabut conservar l’estil casual i artesà del seu títol anterior: el Dolç i Salat. El local, amb reminiscències a granja de tota la vida, combina mobles antics amb uns altres fets a mà; un local encantador i amb un toc naïf que convida a rellegir els  The New Yorker gastats de les prestatgeries mentre sonen els vinils dels setanta.
# None
# “L’ACORD NUCLEAR ÉS L’ÚNICA ESPERANÇA que tenim per millorar la nostra qualitat de vida. Així no podem seguir. Què faré quan, després de llicenciar-me, no trobi feina? ¿Marxar, com fan milers de joves cada any?” La Marian, estudiant de medicina, expressa en veu alta l’interrogant que pesa sobre la consciència de centenars de milers de joves iranians, que en acabar els estudis superiors han de triar entre seguir al costat de les seves famílies o deixar enrere la terra que estimen per trobar a l’estranger les oportunitats que els nega el seu país.
# None
# L’IRAN HA PASSAT DE SER UNA POTÈNCIA MARGINAL a tenir un paper decisiu en els afers de tota la regió. La seva participació en la guerra de Síria, la seva involucració en la lluita contra l’Estat Islàmic a l’Iraq i ara el seu suport fonamental en la rebel·lió dels houthis al Iemen posen en relleu el lideratge iranià al Pròxim Orient. Aquest nou paper no hauria sigut possible sense el consentiment -encara discret- dels Estats Units.
# None
# EL GRÀFIC, AMPLIAT EN PDFSI EL PREACORD PER POSAR SOTA CONTROL internacional les instal·lacions nuclears iranianes supera les reticències dels republicans nord-americans, l’ala dura del règim de Teheran i l’oposició d’Israel, s’haurà esvaït el fantasma d’un Iran armat amb la bomba atòmica. El dossier calent sembla en vies de solució, però una pregunta continua sense resposta: com es pot impedir la proliferació nuclear al Pròxim Orient, la regió més volàtil del planeta?El Tractat de No-proliferació Nuclear (TNP) que aquests dies es revisa a Nova York preveu que els seus signataris, com l’Iran, puguin construir instal·lacions nuclears amb finalitats pacífiques.
# Teheran
# Hegel va destacar el que l’arrogant ignorància d’Occident oblida: el Gran Iran o la Gran Pèrsia acull una de les civilitzacions més antigues i sofisticades del món, cabdal en la història i el present. Per això s’hi va referir com “el primer poble històric”. Hi ha, però, un obstacle estructural: unes relacions marcades per l’intervencionisme occidental i la malfiança.
# None
# DURANT LA CAMPANYA PRESIDENCIAL DEL 2008, el llavors senador d’Illinois, Barack Obama, va afirmar que el govern de George W. Bush cometia un error no parlant amb els seus enemics. I va assegurar que estava disposat a “liderar una diplomàcia forta i de principis amb els líders iranians adequats quan sigui convenient i només si es pot avançar en l’interès dels Estats Units”.
# Illinois
# Fa un parell de setmanes l’ARA oferia als seus lectors el llibre  Camí a l’escola, que relata l’odissea diària de molts nens per poder accedir a una mínima dosi d’educació amb la qual poder-se garantir un futur millor. Aquesta setmana organitzacions i comunitats educatives de tot el món han celebrat la Global Action Week (@globaleducation), una campanya perquè els grans objectius de reducció de l’analfabetisme dels governs mundials tingui més amplitud de mires i no es resigni a l’educació primària.
# None
# “Si no defensem els nostres drets, no ho farà ningú; ara és el moment en què més gent hi hauria d’haver i em sap greu veure el carrer mig buit”. Eren paraules de Carlota Palau, una manifestant de 61 anys que no ocultava la seva decepció en la manifestació del Primer de Maig convocada per CCOO i la UGT que va recórrer ahir els carrers del centre de Barcelona.
# Barcelona
# La majoria de les persones que van a una manifestació com la de l’1 de Maig tenen ja molt poc a perdre. No em refereixo als polítics ni als sindicalistes afiliats. Els primers hi són perquè toca i els segons perquè és el seu dia. Parlo de tota la resta, dels ciutadans que se senten afectats i volen expressar-se. Molts es col·loquen als laterals, acompanyen la multitud una estona o es queden palplantats amb una pancarta que s’han fabricat a casa.
# None
# Barbara Gertz és una més dels milers de nord-americans que han sortit a protestar en els últims mesos. Té 47 anys, viu a Denver (Colorado) i fa tres hores d’autobús per anar a treballar a una gran superfície Walmart, l’empresa amb més empleats del país. Al principi cobrava 8,25 dòlars (7,35 euros) per hora i va passar-se a les matinades per guanyar un parell de dòlars més; ara rep uns 2.
# Denver
# La política monetària del Banc Central Europeu (BCE) ha servit per injectar liquiditat al sistema, però també ha provocat un afebliment de l’euro enfront d’altres monedes de referència en el comerç internacional, com són el dòlar i la lliura esterlina. I això ha provocat, al seu torn, un canvi de paradigma en les destinacions de les exportacions catalanes.
# None
# ¿Algú s’imagina un maratonià que és líder al quilòmetre 40, que està fent una bona marca, que ho té tot de cara per guanyar... però que de cop i volta s’atura i es posa a caminar? Doncs aquesta mateixa metàfora és la que va fer servir Luis Enrique per definir la situació actual del Barça, primer a la Lliga quan falten quatre jornades -comptant la d’avui-.
# None
# Recull de la premsa esportiva del dissabte 2 de maig:L'Esportiu: "Cap concessió"Mundo Deportivo: "La lliga es decideix al sud"Sport: "Avui pot ser un gran dia"Marca: "La batalla... i el combat"As: "La Lliga passa per Sevilla"
# Sevilla
# L’últim cop que el Barça va jugar un partit de Lliga al camp del Còrdova, la penúltima jornada de la temporada 1971-1972, va perdre el títol. Aquella derrota per 1-0 contra un rival que ja havia baixat va marcar una generació, que no veia un títol de Lliga des del 1960 i que per uns dies havia somiat a poder, per fi, superar el Madrid. Però el Còrdova es va imposar i la Lliga es va esfumar.
# Còrdova
# El Barça i el Vic són els dos equips catalans que participen, des d’avui, en la  final four de la Lliga Europea d’hoquei patins. Una competició que es disputa a la ciutat italiana de Bassano. El conjunt d’Osona obrirà foc contra el Porto (17 h, Esport3) i els blaugranes disputaran la segona semifinal contra el Breganze (20.30 h, Esport3). El Barça, vigent campió, parteix com a favorit, tot i que haurà de superar l’escull inicial de jugar el primer partit contra el rival italià, que exerceix d’amfitrió.
# Bassano
# Valentino Rossi ha tingut molts rivals en tota la seva llarga i extensa trajectòria des que va arribar al Mundial de motociclisme. Max Biaggi, Sete Gibernau, Casey Stoner, Jorge Lorenzo... L’italià diu que tots són diferents, que cada rival és únic. “Amb Biaggi no hi va haver mai una gran relació. Amb Sete diria que érem amics, però la nostra relació es va deteriorar a partir del Gran Premi de Qatar del 2004.
# None
# Bona part de les opcions del Vic per guanyar la seva primera Lliga Europea passen per la inspiració sota pals de Carles Grau. L’MVP de l’última Copa, que està a punt de renovar al conjunt vigatà per a dos anys, analitza les opcions del seu equip. Què heu de vigilar més del Porto?
#  És un equip amb un gran potencial golejador, que sempre va a buscar més gols encara que ja guanyi.
# Vic
# Las Vegas viurà aquesta matinada el combat de boxa convertit en el gran negoci esportiu de l’any. El Floyd Mayweather contra Manny Pacquiao (5 de la matinada, per Canal+ i TotalChannel de Mediapro per 12 euros) generarà, entre entrades, drets televisius i publicitat, entre 300 i 400 milions de dòlars de beneficis. Mayweather en 36 minuts -si s’arriba als 12 assalts- cobrarà el mateix que Messi en cinc anys. Pacquiao se n’endurà menys, ja que l’acord perquè Money (Mayweather és anomenat així pel seu gust pels diners) acceptés boxejar passava perquè Pacquiao assumís que la repartició dels guanys fos desigual: 40% per a ell i el 60% restant per al púgil de Michigan.Només en entrades s’han ingressat 14 milions de dòlars més que en l’última Super Bowl, amb preus de 1.500 a 7.500 dòlars. Això sense incloure la revenda, amb entrades valorades en 64.500 dòlars. L’altre gran canal d’injecció serà el televisiu, ja que el combat s’emetrà en 150 països. La publicitat deixarà uns 17 milions; una marca pagarà 2,5 milions de dòlars pels pantalons de Pacquiao.
# Las Vegas
# “La meva mare és una dona molt intel·ligent, amb un gran sentit de l’humor, molt viva, molt ràpida per entendre les coses”. Qui parla així és Miquel Barceló (Felanitx, 1957), un dels noms indiscutibles del panorama artístic internacional, l’artista viu més cotitzat de l’Estat i un fill agraït. La mare, Francisca Artigues (Felanitx, 1926), durant anys pintora amateur de paisatges postimpressionistes -la pintura de moda a la Mallorca d’entre les dècades dels 40 i 70-, és qui va inculcar al fill la passió pel dibuix i la pintura.
# Mallorca
# Sense arribar a la llengua pirotècnica i delirant de Louis Férdinand Céline (1894-1961), la literatura de Michel Houellebecq proposa, recordant un dels títols emblemàtics de l’escriptor francès, un  viatge al fons de la nit. La comparació no pot ser nova: per poc que es coneguin les novel·les d’un i altre, s’hi localitzen dosis similars de malestar, desengany i provocació.
# None
# Inés García Holgado va començar a escoltar les històries dels seus familiars desapareguts durant la Guerra Civil i el franquisme quan era adolescent. Avui aquesta advocada argentina, filla i néta d’exiliats, té 50 anys i en fa quinze que batalla per esbrinar què va passar amb el seu avi i el seu oncle. Quan va començar a investigar estava pràcticament sola.
# None
# Després d’una gira per Mèxic, els barcelonins Dorian arriben a Barcelona per presentar el disc  Diez años y un día, el 9 de maig a la sala Barts. No és exactament un treball amb material nou, tot i que hi ha dues cançons noves, ni tampoc un recopilatori convencional. “Volíem jugar amb el nostre repertori, agafar les cançons dels discos anteriors que s’adapten millor al que som avui i reinterpretar-les amb instruments eminentment acústics: cordes, clavicordis, guitarres acústiques, percussions i el  ronroco, que és un instrument de la família del  charango però amb un so molt més gruixut”, explica Marc Gili, cantant i compositor de Dorian.
# Barcelona
# TV3 ha estat el canal més vist a l'abril a Catalunya, però continua sense poder desempallegar-se de Telecinco, que des que va començar l'any es manté a menys d'un punt de la pública catalana. En aquesta ocasió, la distància entre tots dos canals ha estat de set dècimes.El canal públic ha tancat l'abril amb un 12,4%, una xifra que millora en una dècima el resultat del març però que és el segon més baix de tota la temporada. Telecinco, en canvi, ha baixat del 12,1% a l'11,7%, el pitjor resultat d'aquest 2015. De fet, el canal de Mediaset ha vist com la distància respecte a Antena 3 també s'encongia, malgrat que aquesta cadena també ha anat a la baixa durant l'últim mes. El canal d'Atresmedia havia fet un 11,4% al març –set dècimes menys que Telecinco– i ara ha obtingut amb un 11,3%, però s'ha situat a 0,3 punts de la seva rival.Mentrestant, La 1 continua sense entrar a la lliga de les grans cadenes. El 7,6% de l'abril millora en una dècima el resultat del març, però la deixa encara a gairebé quatre punts del podi i, en canvi, a molt poca distància dels segons canals dels grups privats, per bé que tots dos han anat a la baixa. Així, Cuatro ha passat del 7,3% al 6,9%, i La Sexta ha caigut del 6,8% al 6,6%.Pel que fa a 8TV, ha perdut una dècima i s'ha quedat amb un 3,3%, un resultat que iguala els mínims de la temporada de desembre i gener. Pel que fa als canals temàtics de Televisió de Catalunya, l'Esport3 puja una dècima i se situa en l'1,4%, però els altres dos han anat a la baixa: el Super3/33 ha caigut de l'1,6% a l'1,5%, i el 3/24 ha passat de l'1,5% a l'1,2%.
# None
# La comissió mixta de seguiment del Codi d’Autoregulació sobre Continguts Televisius i Infància va presentar dijous el seu informe corresponent a l’any 2014, que situava Mediaset en una primera posició destacada pel que fa al nombre de queixes rebudes dels espectadors. De les 131 reclamacions presentades durant l’any passat, 95 (és a dir, un 72,5%) corresponien a aquest grup, mentre que Atresmedia en va acumular vint-i-set, Televisió Espanyola set i Net TV i la Forta -la federació de canals autonòmics- en van rebre una cadascuna.
# None
# El turisme és una de les indústries més resistents del món. I una de les que més creixen. Les estadístiques diuen que a partir d’aquest 2015 el trànsit de viatgers arreu del món augmentarà un 5% cada any, segons dades de Boeing, cosa que suposa milers de desplaçaments i milers de persones més viatjant amunt i avall pel planeta. Segons l’Organització Mundial del Turisme (OMT), l’any 2030 hi haurà 1.
# None
# La duquessa de Cambridge, Kate Middleton, podria donar a llum el seu segon fill aquest cap de setmana després que li indueixin el part. És la conclusió a què han arribat diversos mitjans després que l’equip mèdic de l’Hospital St Mary’s -on va néixer fa dos anys el seu primogènit, el príncep Jordi- que l’ha d’assistir es mostrés partidari de provocar el part si no es produeix de manera natural durant els 7 dies posteriors a les 40 setmanes d’embaràs, que es complien el 23 d’abril.
# Cambridge
# Només cal pujar una foto nostra al núvol. Després d’analitzar-la, ens dirà quants anys tenim. O, almenys, quants n’aparentem. És la nova joguina que s’ha inventat Microsoft. La web calcula l’edat a partir d’un sistema d’aprenentatge automàtic després d'indentificar les cares. How-old.net pot deduir l’edat de la persona fotografiada i també si és home o dona.No sempre l’encerta, però acostuma a acostar-s’hi. Barack Obama té 53 anys i la màquina diu que en té 58.Artur Mas en té 59 i la màquina, en canvi, el fa més jove: 56.També es conserven molt bé Madonna (n’hi posa 31 i en té 56) i Hillary Clinton (n’hi posa 40 i en té 67).David Beckam n'ha fet 40 i Microsoft n'hi posa 45.A Justin Bieber el fa més jove (19, i en té 21) i a Messi més gran (37, i en té 27).
# None
# 1. Toño Fraguas (@antoniofraguas), periodista “Si encara s’incompleix la jornada de 8 hores (el dret pel qual va sorgir fa més d’un segle l’#1deMayo), imaginem la resta de drets...”2. Marçal Lladó (@Apagafox), copropietari de Bankrobber “El que reivindiquen potser no, però els sindicalistes són com molt d’una altra època, no?”3. Gabriel Fernàndez (@GabrielFerDiaz), gerent d’una ONG i independent a la llista d’ERC a l’Ajuntament de Sabadell “Pels que ens han precedit, pels que pateixen ara i pels nostres fills: els drets no es demanen, es conquereixen! #1deMaig ”4. Montse Forga (@montseforga), advocada “No m’agrada el concepte classe treballadora, no crec en les classes socials, ni crec que els que l’utilitzen incloguin a tots els que treballen”5. Montserrat Tudela (@Mtudela), directora de la revista ‘Auriga’ “També aprofito l’#1demaig per demanar igualtat laboral de les dones treballadores (#onsónlesdones en els quadres sindicals)”6. Jesús Encinar (@JesusEncinar), fundador del portal Idealista “–Els sindicats reivindiquen llocs de treball de qualitat i salaris dignes. –Molt senzill, que muntin empreses. –No, que *un altre* ho faci. –Ah”7. Gerard Sugranyes (@Gsugranyes), traductor i intèrpret “–I tu on vas pel pont de l’#1deMaig? –No, jo sóc #traductor”8. Feliciano López (@feliciano_lopez), tenista “Enhorabona @RafaelNadal per la teva Medalla d’Or al Mèrit al Treball. Ningú representa aquests valors millor que tu. #Ejemplo”9. Juanjo Talavante (@JJT24601), periodista “La millor Espanya no la representa l’èxit esportiu, sinó la solidaritat i la humanitat. Per exemple, els metges que van de voluntaris al Nepal”10. Araceli Segarra (@Aracelisegarra), alpinista “El Nepal necessita diners, no un altre voluntari per mantenir... tret que siguis metge o enginyer entrenat en això”11. Olga Suanya (@osuanya), antropòloga i periodista “Dos terratrèmols més. Aquest cop a Papua Nova Guinea. La Terra segueix queixant-se i nosaltres sembla que no la vulguem escoltar”
# Sabadell
# “Fer de mestre és un privilegi”, diu el professor de primària Jordi Sedó (61 anys), de l’Escola Giroi de la Garriga. És així perquè “les criatures són com l’argila, si hi poses el dit, hi queda una marca que pot quedar per sempre”. Just per això les exigències de l’ofici són molt altes: es requereix honestedat, sinceritat, respecte i delicadesa.“Els que trien ser mestres per les vacances i els horaris no seran feliços mai, perquè és un ofici molt exigent, que demana tenir clar tot el bé i el mal que pots fer amb les teves accions i paraules”, continua explicant el Jordi, que acaba de publicar el llibre  Fer de mestre (Editorial Malhivern), en què fa revelacions de capçalera sobre l’ofici.
# la Garriga
# Recordo els diumenges a la tarda, que les meves filles tenien molts deures i jo em posava amb elles a treballar a la taula, fent-los companyia, perquè sempre havia d’acabar dibuixos i contes. Per elles això era un consol perquè sentien que no estaven soles fent uns deures que havien d’entregar l’endemà. Jo no sé a casa teva, però a casa meva els deures sempre s’han fet a l’últim moment.
# None
# Susceptibles, impulsius, enamoradissos, insegurs, somiadors... Es diu que tenen el cap ple de pardals. Però, què en sabem realment sobre el que pensen els adolescents? La neurociència ha fet grans progressos en l’estudi del cervell dels joves, que permeten entendre millor algunes de les seves reaccions i evitar estigmatitzar-los pels seus comportaments.
# None
# L’escola on duc el petit dels tres menors d’edat que tinc a càrrec (MEC), i on també van anar els seus germans grans, és la meva escola, la mateixa on vaig anar jo de petita. Quan hi vaig portar els MEC veníem d’un altre centre i vaig voler que hi entressin amb bon peu, convençuts. Com que tot plegat va coincidir amb un sopar de retrobada dels meus excompanys de classe i una vista prèvia a l’escola, vaig confabular-me amb els meus amics.
# None
# En un context en què un de cada quatre infants viu per sota del llindar de la pobresa, Fundesplai va posar en marxa al mes de gener la campanya #botaxlainfancia, una iniciativa que busca situar els drets dels infants a la primera plana social i política. Com? Instant tots els que creguin que la defensa dels drets i la igualtat d’oportunitats en la infància és una prioritat a manifestar-se públicament a través d’un petit gest: fotografiar-se saltant o fent botar una pilota i compartint la imatge a través de les xarxes socials, un gest senzill que ha mobilitzat fins a hores d’ara prop de 10.
# None
# Tampoc ha de ser tan difícil. Vull dir que n’hi ha com a mínim més de la meitat que mai més tornarem a agafar del prestatge. Això per no parlar dels que vam començar i no ens van acabar de fer el pes. O dels que ens van regalar amb tota la bona fe del món sense encertar-la gens ni mica. A més, ja ens ha passat amb altres andròmines de casa i ben bé que ens n’hem sortit.
# None
# Primer dia a l’agrupament escolta. El Marc és el nou, s’incorpora a un grup que es va formar l’any passat i en què tothom ja es coneix. Els caps han ideat dinàmiques perquè els nens es coneguin i facin pinya, i li demanen al Marc que expliqui un acudit. Si els seus companys de grup no es peten de riure, haurà de pagar una penyora. El Marc es planta al davant de la resta de nens i engega un acudit que parla de gallines, ous i pantalons.
# None
# Fins que no tens fills no ets conscient que estem envoltats de males influències. De petit m’agradava el Mazinger Z i tenia joguines bèl·liques, però això no em va convertir en un monstre. No va ser fruit de l’atzar, sinó que els meus pares es van esforçar perquè fos una persona educada, pacífica i dialogant. Als meus fills no els vull protegir en excés, però sí que, amb la meva dona, els allunyem de tot allò que no els pertoca per a l’edat.
# None
# Diem el teu nom i ja no hauríem de dir res més. Pronunciar-lo i pensar en tu i en els teus. Acompanyar el seu dolor amb el silenci i confiar que el temps anirà amorosint una pena que mai no deixarà d’existir. Confiar en la necessitat que la vida continuï.Dir el teu nom i renunciar en aquests moments de dol intens a l’acte tan humà de buscar etiquetes que expliquin uns fets que mai no havíem imaginat que passarien en un institut de la nostra ciutat.
# None
# Molt sovint, i en situacions molt variades, es comenta que s’han perdut els valors. Aquest comentari es fa a casa, al carrer, al mercat i en llocs on hi ha persones de totes les edats. Ara bé, és cert que potser el sentim més entre la gent gran i especialment en relació amb com respon la canalla i el jovent. La frase més utilitzada quan es fan aquests comentaris és: “Avui en dia s’han perdut els valors! Això abans no passava!”Si mirem de concretar millor el que s’enyora, potser té a veure únicament amb unes conductes que eren bàsicament aspectes formals i que es consideraven com a respecte.
# None
# Les irades reaccions des del PP a la proposta de l’assessor de Ciutadans Luis Garicano, en el sentit que potser caldrà replantejar algunes línies d’AVE si no superen un estudi de costos i beneficis, demostren que a Espanya encara és difícil debatre amb un cert grau de racionalitat econòmica. La realitat és que Garicano ha posat sobre la taula una qüestió que tant el PP com el PSOE han evitat afrontar fins ara.
# None
# Ve’t aquí que els valencians han tingut amb mi la delicadíssima atenció de nomenar-me mantenidor dels Jocs Florals del Rat-Penat, atenció que jo els agraeixo moltíssim i que m’ha proporcionat l’avinentesa de fer un viatge ràpid a la celestial ciutat mediterrània; jo, a València, hi he estat unes quantes vegades. [...] La festa del Rat-Penat és de les coses més pomposes que es celebren al món.
# València
# LA PORTADA EN PDFL'Iran: més enllà de l'acord nuclear. La generació més jove n’espera reformes i oportunitats.També trobareu a l''ARA Planeta' d'aquest dissabte:Obama s'hi juga el llegat. El pacte amb l’Iran obre una nova era.La nova hegemonia de Teheran. Un actor militar clau a Síria, l’Iraq i el Iemen.Planeta nuclear. El Tractat de No-proliferació, o la doble vara de mesura amb l’Iran i Israel.
# Teheran
#
# None
#
# None
# Cat@Salut-La meva Salut  (Cat@Health-My health) is a tool that can be accessed via the internet, but which is personal and non-transferable. On this website, any patient can access their clinical records on-line -- from the place, time, and device (tablet, mobile phone, or computer) of their choice--: medical reports, test results, vaccination schedules, or diagnostic tests.As reported earlier by this newspaper, the new tool will also allow patients to look up their medication plan or access a living will document. In the near term, new services will be added: it will be possible to do paperwork on-line --such as to request the reimbursement of the euro per prescription-- and users will even be able to add data to their patient record that they have collected themselves. The goal, according to Josep Maria Padrosa, Director of CatSalut, is to empower the patient in matters of their own health.Users can access this volume of information with a user name and a password that they can request in their Primary Care Center (CAP). Since the beginning of the trial period, the CAPs have processed more than 10,000 requests.This new service has already been implemented in the healthcare regions of Tarragona, Lleida, Girona, the Terres de l´Ebre, the Pyrenees, and Central Catalonia. Between the months of May and July it will be implemented in Barcelona and its metropolitan area, the Maresme, and the eastern and western Vallès.
# Tarragona
# Aznar managed to fool some newspaper editors with the ETA story on 11 March 2004. Over the next few days, text messages and international newspapers exposed the fact that a lying government had tried to muddy the waters about the train bombings in Madrid. Now, nothing makes the PP, Foreign Minister Margallo and their friends more uncomfortable than the Catalan independence process being mentioned in foreign media. That is because they don't control them and because, despite Madrid’s meddling, more and more journalists are relying on Catalan sources and the result is closer to reality than to Rajoy's wishes.Mas' international strategy receives all sorts of attacks that are just ridiculous, because they contradict each other. The same people who ridicule it claiming that it is futile are also angered by the fact that it is being carried out. They deny it having any influence and decry the expenses it entails. Now the PP claims that journalists who sympathise with the process are being bribed and have their trips paid for. You can imagine them waiting for the press cuttings every morning, laughing and being outraged at the same time, looking through each piece of news, stating that it is nonsense and then finding it very worrying.This reaction confirms that the path we have taken is the right one. It was vital, it still is and will be increasingly so. If they are so worried about it, then Rajoy's government has a great opportunity to improve its international image and to spare itself criticism: to allow Spain, on the 27th of September, to be seen as a democratic state and to allow all Catalans living abroad to vote without any hitches. Just in case it doesn't happen this year either, which would be very serious indeed --although sadly foreseeable-- we will have to start warning the foreign media, as it is the only thing which makes them nervous.
# Madrid
# El Manresa s'imposa en el marcador en un enfrontament clau per sortir de la zona de descensEl president de l'ACB entrega a Josep Vives la placa commemorativa dels 1000 partits del conjunt manresà a la Lliga
#
#
# Manresa
# Una aula de P3 que de moment es vincularà a la Sèquia serà l'embrió del centre a la carretera Santpedor i les Bases
# la Sèquia
# La Generalitat argumenta que des que l'explotació és a mans israelianes la qualitat dels rius no ha variat
# None
# La nova distribució de la mostra fa créixer el recinte firal convertint un tram reservat als cotxes en zona de vianants
# None
# Ferran Civil haurà d'afrontar un nou judici en què la fiscalia li demana 5.000 euros de multa
# None
# Algunes activitats que s'hi feien s'han traslladat al Nexe, a l'espera d'un local que llogarà l'Ajuntament
# None
# Les complicacions de trànsit van tenir lloc sobretot al matí i al migdia entre Berga i Gironella
# Berga
# El capellà, de 95 anys d'edat, acabava de publicar les seves memòries, 'El sac dels records'
# None
# Les votacions es poden fer a través del web, Facebook o Twitter amb els hashtags #premiestrella i #premiestrellat
# None
# Si la justícia ho confirma, els populars hauran de recórrer davant del Tribunal Constitucional
# None
# Una llarga filera de persones ocupava ahir a mig matí l'esplanada de davant de l'ermita
# None
# Regió7 posa cara a cara el regidor d'Urbanisme de l'Ajuntament i el polític que més s'ha significat en la crítica
# None
# Els seients verds ja s'han instal·lat al primer tram del passeig i el preu per seure-hi es manté en els 50 cèntims
# None
# Endavant Cerdanya denuncia "manca de previsió" en la gestió del govern de Puigcerdà
# Puigcerdà
# El reconegut escultor solsoní va morir dijous als 57 anys deixant un gran llegat tant a la ciutat com arreu del país
# None

# %%
i=0
for x in array_noticies:
    if x[4]!='None':
        i+=1
        print i,
        print x[4]
# Out:
# 1 Berlín
# 2 Barcelona
# 3 Berlín
# 4 Nova York
# 5 Castelló
# 6 Madrid
# 7 Qatar
# 8 Andalusia
# 9 Hospital del Mar
# 10 Premià de Mar
# 11 Reus
# 12 Kàtmandu
# 13 Pyongyang
# 14 Donetsk
# 15 Baltimore
# 16 Milà
# 17 Barcelona
# 18 Poble-sec
# 19 Barcelona
# 20 el Carmel
# 21 Pou de la Figuera
# 22 Teheran
# 23 Illinois
# 24 Barcelona
# 25 Denver
# 26 Sevilla
# 27 Còrdova
# 28 Bassano
# 29 Vic
# 30 Las Vegas
# 31 Mallorca
# 32 Barcelona
# 33 Cambridge
# 34 Sabadell
# 35 la Garriga
# 36 València
# 37 Teheran
# 38 Tarragona
# 39 Madrid
# 40 Manresa
# 41 la Sèquia
# 42 Berga
# 43 Puigcerdà

# %%
# We set the values to the train database
for noti in db.train_set.find():
    print noti

# %%
text = 'Tots els gats son de Sant Cugat del Valles.'
text = text.replace('.','').split(' ')

cities =  {"Sant Cugat del Valles":["Sant","Cugat","del","Valles"]}

found_match = False
for word in text:
    if found_match:        
        cityTest = cityTest
    else:
        cityTest = ''
    found_match = False
    for city in cities.keys():

        if word in cities[city]:
            cityTest += word + ' '
            found_match = True        
        if cityTest.split(' ')[0:-1] == city.split(' '):
            print city    #Print if it found a city.
# Out:
# Sant Cugat del Valles

# %%
mides = []
clean_all_cities = []
with open('all_city_names.txt') as f:
    for linia in (line.strip() for line in f):
        mides.append(len(linia.split(',')[0].split(' ')))
        print linia.split(',')[0].split(' ') # treiem el que hi hagi després de la ','
        clean_all_cities.append(linia.split(',')[0].replace('*','').split(' '))
        
    print 'La longitud dels noms de pobles catalans va de', min(mides), 'a', max(mides), 'paraules.'
# Out:
# ['Abella']
# ['Abella', 'de', 'la', 'Conca']
# ['Abrera']
# ['\xc3\x80ger']
# ['Agramunt']
# ['Aguilar', 'de', 'Segarra']
# ['Agullana']
# ['Aiguafreda']
# ['Aiguaviva']
# ['Aitona']
# ['Alam\xc3\xbas']
# ['Al\xc3\xa0s']
# ['Albag\xc3\xa9s']
# ['Albany\xc3\xa0']
# ['Albat\xc3\xa0rrec']
# ['Albesa']
# ['Albi']
# ['Albinyana']
# ['Albiol']
# ['Albons']
# ['Alcanar']
# ['Alcan\xc3\xb3']
# ['Alcarr\xc3\xa0s']
# ['Alcoletge']
# ['Alcover']
# ['Aldea']
# ['Aldover']
# ['Aleixar']
# ['Alella']
# ['Alfara', 'de', 'Carles']
# ['Alfarr\xc3\xa0s']
# ['Alf\xc3\xa9s']
# ['Alforja']
# ['Algerri']
# ['Alguaire']
# ['Alins']
# ['Ali\xc3\xb3']
# ['All']
# ['Almacelles']
# ['Almatret']
# ['Almenar']
# ['Almoster']
# ['Al\xc3\xb2s', 'de', 'Balaguer']
# ['Alp']
# ['Alpens']
# ['Alpicat']
# ['Altafulla']
# ['Amer']
# ['Ametlla', 'del', 'Vall\xc3\xa8s']
# ['Ametlla', 'de', 'Mar']
# ['Ampolla']
# ['Amposta']
# ['Angl\xc3\xa8s']
# ['Anglesola']
# ['Anserall']
# ['Ansovell']
# ['Arbeca']
# ['Arbo\xc3\xa7']
# ['Arbol\xc3\xad']
# ['Arb\xc3\xbacies']
# ['Arenys', 'de', 'Mar']
# ['Arenys', 'de', 'Munt']
# ['Argelaguer']
# ['Argen\xc3\xa7ola']
# ['Argentera']
# ['Argentona']
# ['Armentera']
# ['Arnes']
# ['Arres', 'de', 'Jos']
# ['Ars\xc3\xa8guel']
# ['Art\xc3\xa9s']
# ['Artesa', 'de', 'Lleida']
# ['Artesa', 'de', 'Segre']
# ['Asc\xc3\xb3']
# ['Aspa']
# ['Avellanes']
# ['Avi\xc3\xa0']
# ['Aviny\xc3\xb3']
# ['Avinyonet', 'de', 'Puigvent\xc3\xb3s']
# ['Aviny\xc3\xb3', 'Nou']
# ['Badalona']
# ['Badia', 'del', 'Vall\xc3\xa8s']
# ['Bag\xc3\xa0']
# ['Balaguer']
# ['Balsareny']
# ['Banyeres', 'del', 'Pened\xc3\xa8s']
# ['Banyoles']
# ['Barbens']
# ['Barber\xc3\xa0', 'de', 'la', 'Conca']
# ['Barber\xc3\xa0', 'del', 'Vall\xc3\xa8s']
# ['Barcelona']
# ['Barruera']
# ['B\xc3\xa0scara']
# ['Bassella']
# ['Batea']
# ['Bausen']
# ['Begues']
# ['Begur']
# ['Belianes']
# ['Bellaguarda']
# ['Bellcaire', "d'Empord\xc3\xa0"]
# ['Bellcaire', "d'Urgell"]
# ['Bell-lloc', "d'Urgell"]
# ['Bellmunt', 'del', 'Priorat']
# ['Bellmunt', "d'Urgell"]
# ['Bellprat']
# ['Bellpuig']
# ['Bellvei']
# ['Bellver', 'de', 'Cerdanya']
# ['Bellv\xc3\xads']
# ['Benavent', 'de', 'Segri\xc3\xa0']
# ['Benifallet']
# ['Benissanet']
# ['Berga']
# ['Besal\xc3\xba']
# ['Bescan\xc3\xb3']
# ['Beuda']
# ['Bigues']
# ['Biosca']
# ['Bisbal', 'de', 'Falset']
# ['Bisbal', 'del', 'Pened\xc3\xa8s']
# ['Bisbal', "d'Empord\xc3\xa0"]
# ['Biure']
# ['Blancafort']
# ['Blanes']
# ['Boadella', "d'Empord\xc3\xa0"]
# ['Bolvir']
# ['Bonastre']
# ['Bonmat\xc3\xad']
# ['B\xc3\xb2rdes']
# ['Bordils']
# ['Borges', 'Blanques']
# ['Borges', 'del', 'Camp']
# ['Borr\xc3\xa0s']
# ['Borrass\xc3\xa0']
# ['Borred\xc3\xa0']
# ['Boss\xc3\xb2st']
# ['Bot']
# ['Botarell']
# ['Bou']
# ['Bovera']
# ['Br\xc3\xa0fim']
# ['Branques']
# ['Breda']
# ['Bruc']
# ['Brull']
# ['Brunyola']
# ['Burg']
# ['Cabac\xc3\xa9s', '*']
# ['Cabanabona']
# ['Cabanelles']
# ['Cabanes']
# ['Cabanyes']
# ['Cab\xc3\xb3']
# ['Cabra', 'del', 'Camp']
# ['Cabrera', 'de', 'Mar']
# ['Cabrils']
# ['Cadaqu\xc3\xa9s']
# ['Calaf']
# ['Calafell']
# ['Calders']
# ['Caldes', 'de', 'Malavella']
# ['Caldes', 'de', 'Montbui']
# ['Caldes', "d'Estrac"]
# ['Calella']
# ['Calldetenes']
# ['Call\xc3\xbas']
# ['Calonge']
# ['Camallera']
# ['Camarasa']
# ['Camarles']
# ['Cambrils']
# ['Cambrils']
# ['Cam\xc3\xb3s']
# ['Campdev\xc3\xa0nol']
# ['Campelles']
# ['Campins']
# ['Campllong']
# ['Camprodon']
# ['Canaletes']
# ['Canejan']
# ['Canet', "d'Adri"]
# ['Canet', 'de', 'Mar']
# ['Canonja']
# ['Canovelles']
# ['C\xc3\xa0noves']
# ['Cantallops']
# ['Canyelles']
# ['Capafonts']
# ['Cap\xc3\xa7anes']
# ['Capellades']
# ['Capmany', '*']
# ['Capolat']
# ['Cardedeu']
# ['Cardona']
# ['Carme']
# ['Caseres']
# ['Cass\xc3\xa0', 'de', 'la', 'Selva']
# ['Casserres']
# ['Castellar', 'de', 'la', 'Ribera']
# ['Castellar', 'del', 'Vall\xc3\xa8s']
# ['Castellar', 'de', "n'Hug"]
# ['Castellbisbal']
# ['Castellcir']
# ['Castelldans']
# ['Castelldefels']
# ['Castell', 'de', "l'Areny"]
# ['Castellfollit', 'de', 'la', 'Roca']
# ['Castellfollit', 'del', 'Boix']
# ['Castellfollit', 'de', 'Riubreg\xc3\xb3s']
# ['Castellgal\xc3\xad']
# ['Castellnou', 'de', 'Bages']
# ['Castellnou', 'de', 'Seana']
# ['Castell\xc3\xb3', 'de', 'Farfanya']
# ['Castell\xc3\xb3', "d'Emp\xc3\xbaries"]
# ['Castellol\xc3\xad']
# ['Castellser\xc3\xa0']
# ['Castellter\xc3\xa7ol']
# ['Castellvell', 'del', 'Camp']
# ['Castellv\xc3\xad', 'de', 'Rosanes']
# ['Catllar']
# ['Cellera', 'de', 'Ter']
# ['Celr\xc3\xa0']
# ['Centelles']
# ['Cercs']
# ['Cerdanyola', 'del', 'Vall\xc3\xa8s']
# ['Cervell\xc3\xb3']
# ['Cervera']
# ['Cervi\xc3\xa0', 'de', 'les', 'Garrigues']
# ['Cervi\xc3\xa0', 'de', 'Ter']
# ['Cistella']
# ['Ciutadilla']
# ['Clariana', 'de', 'Cardener']
# ['Cogul']
# ['Colera']
# ['Collbat\xc3\xb3']
# ['Colldejou']
# ['Coll', 'de', 'Narg\xc3\xb3']
# ['Collsuspina']
# ['Colomers']
# ['Coma']
# ['Conesa']
# ['Constant\xc3\xad']
# ['Copons']
# ['Corbera', "d'Ebre"]
# ['Corbera', 'de', 'Llobregat']
# ['Corbins']
# ['Cor\xc3\xa7\xc3\xa0']
# ['Cornell\xc3\xa0', 'de', 'Llobregat']
# ['Cornell\xc3\xa0', 'del', 'Terri']
# ['Cornudella', 'de', 'Montsant']
# ['Corr\xc3\xb3', "d'Avall"]
# ['Creixell']
# ['Crespi\xc3\xa0']
# ['Cubelles']
# ['Cubells']
# ['Cunit']
# ['Curullada']
# ['Darnius']
# ['Das']
# ['Deltebre']
# ['Dosrius']
# ['Duesaig\xc3\xbces']
# ['Dusfort']
# ['Escala']
# ['Esparreguera']
# ['Espinelves']
# ['Espluga', 'Calba']
# ['Espluga', 'de', 'Francol\xc3\xad']
# ['Esplugues', 'de', 'Llobregat']
# ['Espolla']
# ['Esponell\xc3\xa0']
# ['Espot']
# ['Espunyola']
# ['Estamariu']
# ['Estany']
# ['Estar\xc3\xa0s']
# ['Esterri', "d'\xc3\x80neu"]
# ['Esterri', 'de', 'Card\xc3\xb3s']
# ['Falset']
# ['Far', "d'Empord\xc3\xa0"]
# ['Fatarella']
# ['Febr\xc3\xb3']
# ['Figar\xc3\xb3', '*']
# ['F\xc3\xadgols']
# ['F\xc3\xadgols']
# ['Figuera']
# ['Figueres']
# ['Figuerola', 'del', 'Camp']
# ['Fla\xc3\xa7\xc3\xa0']
# ['Flix']
# ['Floresta']
# ['Fogars', 'de', 'la', 'Selva']
# ['Foix\xc3\xa0']
# ['Folgueroles']
# ['Fondarella']
# ['Fonollosa']
# ['Fontanilles']
# ['Fontcoberta']
# ['Foradada']
# ['For\xc3\xa8s']
# ['Fornells', 'de', 'la', 'Selva']
# ['Forti\xc3\xa0']
# ['Freginals']
# ['Fuliola']
# ['Fulleda']
# ['Gai\xc3\xa0']
# ['Galera']
# ['Gallifa']
# ['Gandesa']
# ['Garcia']
# ['Garidells']
# ['Garriga']
# ['Garrig\xc3\xa0s']
# ['Garrigoles']
# ['Garriguella']
# ['Gav\xc3\xa0']
# ['Gavet', 'de', 'la', 'Conca']
# ['Gelida']
# ['Ger']
# ['Gerri', 'de', 'la', 'Sal']
# ['Gimenells']
# ['Ginestar']
# ['Girona']
# ['Gironella']
# ['Gisclareny']
# ['Godall']
# ['Golm\xc3\xa9s']
# ['Gombr\xc3\xa8n']
# ['Gornal']
# ['G\xc3\xb3sol']
# ['Granada']
# ['Granadella']
# ['Granera']
# ['Granja', "d'Escarp"]
# ['Granollers']
# ['Granyena', 'de', 'les', 'Garrigues']
# ['Granyena', 'de', 'Segarra']
# ['Gratallops']
# ['Gualba']
# ['Gualta']
# ['Gualter']
# ['Gu\xc3\xa0rdia', 'de', 'Tremp']
# ['Guardiola', 'de', 'Bergued\xc3\xa0']
# ['Guardiola', 'de', 'Font-rub\xc3\xad']
# ['Guiamets']
# ['Guils', 'de', 'Cerdanya']
# ['Guimer\xc3\xa0']
# ['Guingueta', "d'\xc3\x80neu"]
# ['Guissona']
# ['Gurb']
# ['Horta', 'de', 'Sant', 'Joan']
# ['Hospitalet', 'de', 'Llobregat']
# ['Hostalets', 'de', 'Baleny\xc3\xa0']
# ['Hostalets', 'de', 'Pierola']
# ['Hostalnou', 'de', 'Bianya']
# ['Hostalric']
# ['Igualada']
# ['Isona']
# ['Ivars', 'de', 'Noguera']
# ['Ivars', "d'Urgell"]
# ['Ivorra']
# ['Jafre']
# ['Jonquera']
# ['Jorba']
# ['Jui\xc3\xa0']
# ['Ju\xc3\xafny\xc3\xa0']
# ['Juncosa']
# ['Juncosa', 'del', 'Montmell']
# ['Juneda']
# ['Lavit']
# ['Les']
# ['Linyola']
# ['Llacuna']
# ['Llad\xc3\xb3', '*']
# ['Lladorre']
# ['Lladurs']
# ['Llagosta']
# ['Llagostera']
# ['Llambilles']
# ['Llanars']
# ['Llan\xc3\xa7\xc3\xa0']
# ['Llardecans']
# ['Llavors\xc3\xad']
# ['Lleida']
# ['Llers']
# ['Lles', 'de', 'Cerdanya']
# ['Lli\xc3\xa7\xc3\xa0', "d'Amunt"]
# ['Lli\xc3\xa7\xc3\xa0', 'de', 'Vall']
# ['Llimiana']
# ['Llinars']
# ['Llinars', 'del', 'Vall\xc3\xa8s']
# ['Ll\xc3\xadvia']
# ['Lloar']
# ['Llobera']
# ['Llorac']
# ['Lloren\xc3\xa7', 'del', 'Pened\xc3\xa8s']
# ['Lloret', 'de', 'Mar']
# ['Llosses']
# ['Ma\xc3\xa7anet', 'de', 'Cabrenys']
# ['Ma\xc3\xa7anet', 'de', 'la', 'Selva']
# ['Madremanya']
# ['Mai\xc3\xa0', 'de', 'Montcal']
# ['Maials']
# ['Mald\xc3\xa0']
# ['Malgrat', 'de', 'Mar']
# ['Malla']
# ['Manlleu']
# ['Manresa']
# ['Mar\xc3\xa7\xc3\xa0']
# ['Margalef']
# ['Marganell']
# ['Martinet']
# ['Martorell']
# ['Martorelles']
# ['Marz\xc3\xa0']
# ['Masarac']
# ['Mas', 'de', 'Barberans']
# ['Masdenverge']
# ['Masies', 'de', 'Roda']
# ['Masies', 'de', 'Voltreg\xc3\xa0']
# ['Maslloren\xc3\xa7']
# ['Masnou']
# ['Mas\xc3\xb3']
# ['Maspujols']
# ['Masquefa']
# ['Masroig']
# ['Massalcoreig']
# ['Massanes', '*']
# ['Massoteres']
# ['Mata']
# ['Matadepera']
# ['Matar\xc3\xb3']
# ['Men\xc3\xa0rguens']
# ['Meranges']
# ['Mieres']
# ['Mil\xc3\xa0']
# ['Miracle']
# ['Miralcamp']
# ['Miravet']
# ['Moi\xc3\xa0']
# ['Molar']
# ['Molins', 'de', 'Rei']
# ['Mollerussa']
# ['Mollet', 'del', 'Vall\xc3\xa8s']
# ['Mollet', 'de', 'Peralada']
# ['Moll\xc3\xb3']
# ['Molsosa']
# ['Monistrol', 'de', 'Calders']
# ['Monistrol', 'de', 'Montserrat']
# ['Monjos']
# ['Montagut']
# ['Montblanc']
# ['Montbri\xc3\xb3', 'del', 'Camp']
# ['Montcada']
# ['Montclar']
# ['Montesquiu']
# ['Montferrer']
# ['Montferri']
# ['Montgai']
# ['Montgat']
# ['Montmajor']
# ['Montmaneu']
# ['Montmel\xc3\xb3']
# ['Montoliu', 'de', 'Lleida']
# ['Montoliu', 'de', 'Segarra']
# ['Montorn\xc3\xa8s', 'del', 'Vall\xc3\xa8s']
# ['Montorn\xc3\xa8s', 'de', 'Segarra']
# ['Mont-ral']
# ['Mont-ras']
# ['Mont-roig', 'del', 'Camp']
# ['Montseny']
# ['M\xc3\xb3ra', "d'Ebre"]
# ['M\xc3\xb3ra', 'la', 'Nova']
# ['Morell']
# ['Morera', 'de', 'Montsant']
# ['Mosqueroles']
# ['M\xc3\xbania']
# ['Muntanyola']
# ['Mura']
# ['Nalec']
# ['Navarcles']
# ['Nav\xc3\xa0s', '*']
# ['Navata']
# ['Nav\xc3\xa8s']
# ['Nou', 'de', 'Bergued\xc3\xa0']
# ['Nou', 'de', 'Gai\xc3\xa0']
# ['Noves', 'de', 'Segre']
# ['Nulles']
# ['\xc3\x92dena']
# ['Ogassa']
# ['Olesa', 'de', 'Bonesvalls']
# ['Olesa', 'de', 'Montserrat']
# ['Oliana']
# ['Oliola']
# ['Olivella']
# ['Olost']
# ['Olot']
# ['Oluges']
# ['Olvan']
# ['Omellons']
# ['Omells', 'de', 'na', 'Gaia']
# ['Ordis']
# ['Organy\xc3\xa0']
# ['Orist\xc3\xa0']
# ['\xc3\x92rrius']
# ['Os', 'de', 'Balaguer']
# ['Osor']
# ['Oss\xc3\xb3', 'de', 'Si\xc3\xb3']
# ['Pacs', 'del', 'Pened\xc3\xa8s']
# ['Palafolls']
# ['Palafrugell']
# ['Palam\xc3\xb3s']
# ['Palau', "d'Anglesola"]
# ['Palau-sator']
# ['Palau-saverdera']
# ['Palau-solit\xc3\xa0', 'i', 'Plegamans']
# ['Pallaresos']
# ['Pallargues']
# ['Pallej\xc3\xa0']
# ['Palma', "d'Ebre"]
# ['Palma', 'de', 'Cervell\xc3\xb3']
# ['Palol', 'de', 'Revardit']
# ['Pals']
# ['Papiol']
# ['Pardines']
# ['Parets', 'del', 'Vall\xc3\xa8s']
# ['Parlav\xc3\xa0']
# ['Passanant']
# ['Pau']
# ['Pa\xc3\xbcls']
# ['Penelles']
# ['Pera']
# ['Perafita']
# ['Perafort']
# ['Peralada']
# ['Peramola']
# ['Perell\xc3\xb3']
# ['Pi', 'de', 'Sant', 'Just']
# ['Piera']
# ['Piles']
# ['Pineda', 'de', 'Mar']
# ['Pinell', 'de', 'Brai']
# ['Pin\xc3\xb3s']
# ['Pira']
# ['Pla', 'del', 'Pened\xc3\xa8s']
# ['Pla', 'de', 'Santa', 'Maria']
# ['Pla', 'de', 'Sant', 'Tirs']
# ['Planes', "d'Hostoles"]
# ['Planoles']
# ['Platja', "d'Aro"]
# ['Poal']
# ['Pobla', 'de', 'C\xc3\xa9rvoles']
# ['Pobla', 'de', 'Claramunt']
# ['Pobla', 'de', 'Lillet']
# ['Pobla', 'de', 'Mafumet']
# ['Pobla', 'de', 'Massaluca']
# ['Pobla', 'de', 'Montorn\xc3\xa8s']
# ['Pobla', 'de', 'Segur']
# ['Poboleda']
# ['Poliny\xc3\xa0']
# ['Pont', "d'Armentera"]
# ['Pont', 'de', 'Bar']
# ['Pont', 'de', 'Claverol']
# ['Pont', 'de', 'Molins']
# ['Pont', 'de', 'Suert']
# ['Pont', 'de', 'Vilomara']
# ['Pontils']
# ['Pontons']
# ['Pont\xc3\xb3s']
# ['Ponts']
# ['Porrera']
# ['Portbou']
# ['Port', 'de', 'la', 'Selva']
# ['Portella']
# ['Pradell', 'de', 'la', 'Teixeta']
# ['Prades']
# ['Prat', 'de', 'Comte']
# ['Prat', 'de', 'Llobregat']
# ['Pratdip']
# ['Prats']
# ['Prats', 'de', 'Llu\xc3\xa7an\xc3\xa8s']
# ['Prats', 'de', 'Rei']
# ['Preixana']
# ['Preixens']
# ['Premi\xc3\xa0', 'de', 'Dalt']
# ['Premi\xc3\xa0', 'de', 'Mar']
# ['Preses']
# ['Prullans']
# ['Puigcerd\xc3\xa0']
# ['Puigd\xc3\xa0lber']
# ['Puiggr\xc3\xb2s']
# ['Puigpelat']
# ['Puig-reig']
# ['Puigverd', "d'Agramunt"]
# ['Puigverd', 'de', 'Lleida']
# ['Pujalt']
# ['Quar']
# ['Quart']
# ['Queralbs']
# ['Querol']
# ['Rab\xc3\xb3s']
# ['Rajadell']
# ['Rasquera']
# ['Regenc\xc3\xb3s']
# ['Rellinars']
# ['Renau']
# ['Reus']
# ['Rialp', '*']
# ['Riba']
# ['Riba-roja', "d'Ebre"]
# ['Ribera', 'de', 'Card\xc3\xb3s']
# ['Ribes', 'de', 'Freser']
# ['Riera', 'de', 'Gai\xc3\xa0']
# ['Ripoll']
# ['Ripollet']
# ['Riudarenes']
# ['Riudaura']
# ['Riudecanyes']
# ['Riu', 'de', 'Cerdanya']
# ['Riudecols']
# ['Riudellots', 'de', 'la', 'Selva']
# ['Riudoms']
# ['Riumors']
# ['Roca', 'del', 'Vall\xc3\xa8s']
# ['Rocafort', 'de', 'Queralt']
# ['Roda', 'de', 'Bar\xc3\xa0', '*']
# ['Roda', 'de', 'Ter']
# ['Rodony\xc3\xa0']
# ['Roquetes']
# ['Roses']
# ['Rossell\xc3\xb3']
# ['Rourell']
# ['Rub\xc3\xad']
# ['Rubi\xc3\xb3']
# ['Rupi\xc3\xa0']
# ['Rupit']
# ['Sabadell']
# ['Sag\xc3\xa0s']
# ['Sagrera']
# ['Salard\xc3\xba']
# ['Sal\xc3\xa0s', 'de', 'Pallars']
# ['Saldes']
# ['Sales', 'de', 'Llierca']
# ['Sallent']
# ['Salom\xc3\xb3']
# ['Salou']
# ['Salt']
# ['Salv\xc3\xa0']
# ['Sana\xc3\xbcja']
# ['Santa', 'B\xc3\xa0rbara']
# ['Santa', 'Cec\xc3\xadlia', 'de', 'Voltreg\xc3\xa0']
# ['Santa', 'Coloma', 'de', 'Cervell\xc3\xb3']
# ['Santa', 'Coloma', 'de', 'Farners']
# ['Santa', 'Coloma', 'de', 'Gramenet']
# ['Santa', 'Coloma', 'de', 'Queralt']
# ['Santa', 'Cristina', "d'Aro"]
# ['Sant', 'Adri\xc3\xa0', 'de', 'Bes\xc3\xb2s']
# ['Santa', 'Eug\xc3\xa8nia', 'de', 'Berga']
# ['Santa', 'Eul\xc3\xa0lia']
# ['Santa', 'Eul\xc3\xa0lia', 'de', 'Puig-oriol']
# ['Santa', 'Eul\xc3\xa0lia', 'de', 'Riuprimer']
# ['Santa', 'Fe', 'del', 'Pened\xc3\xa8s']
# ['Sant', 'Agust\xc3\xad', 'de', 'Llu\xc3\xa7an\xc3\xa8s']
# ['Santa', 'Llogaia', "d'\xc3\x80lguema"]
# ['Santa', 'Margarida', 'de', 'Montbui']
# ['Santa', 'Maria', 'de', 'Besora']
# ['Santa', 'Maria', 'de', 'Corc\xc3\xb3']
# ['Santa', 'Maria', 'de', 'Martorelles']
# ['Santa', 'Maria', 'de', 'Merl\xc3\xa8s']
# ['Santa', 'Maria', 'de', 'Miralles']
# ['Santa', 'Maria', 'de', 'Palautordera']
# ['Santa', 'Maria', "d'Ol\xc3\xb3"]
# ['Sant', 'Andreu', 'de', 'la', 'Barca']
# ['Sant', 'Andreu', 'de', 'Llavaneres']
# ['Sant', 'Andreu', 'Salou']
# ['Sant', 'Antol\xc3\xad', 'i', 'Vilanova']
# ['Sant', 'Antoni', 'de', 'Vilamajor']
# ['Santa', 'Oliva']
# ['Santa', 'Pau']
# ['Santa', 'Perp\xc3\xa8tua', 'de', 'Mogoda']
# ['Santa', 'Susanna']
# ['Sant', 'Bartomeu', 'del', 'Grau']
# ['Sant', 'Boi', 'de', 'Llobregat']
# ['Sant', 'Boi', 'de', 'Llu\xc3\xa7an\xc3\xa8s']
# ['Sant', 'Carles', 'de', 'la', 'R\xc3\xa0pita']
# ['Sant', 'Cebri\xc3\xa0', 'de', 'Vallalta']
# ['Sant', 'Celoni']
# ['Sant', 'Climen\xc3\xa7']
# ['Sant', 'Climent', 'de', 'Llobregat']
# ['Sant', 'Climent', 'Sescebes']
# ['Sant', 'Cugat', 'del', 'Vall\xc3\xa8s']
# ['Sant', 'Cugat', 'Sesgarrigues']
# ['Santes', 'Creus']
# ['Sant', 'Esteve', 'de', 'la', 'Sarga']
# ['Sant', 'Esteve', 'de', 'Ll\xc3\xa9mena']
# ['Sant', 'Esteve', "d'en", 'Bas']
# ['Sant', 'Esteve', 'de', 'Palautordera']
# ['Sant', 'Esteve', 'Sesrovires']
# ['Sant', 'Feliu', 'de', 'Buixalleu']
# ['Sant', 'Feliu', 'de', 'Codines']
# ['Sant', 'Feliu', 'de', 'Gu\xc3\xadxols']
# ['Sant', 'Feliu', 'de', 'Llobregat']
# ['Sant', 'Feliu', 'de', 'Pallerols']
# ['Sant', 'Feliu', 'Sasserra']
# ['Sant', 'Fost', 'de', 'Campsentelles']
# ['Sant', 'Fruit\xc3\xb3s', 'de', 'Bages']
# ['Sant', 'Gregori']
# ['Sant', 'Guim', 'de', 'Freixenet']
# ['Sant', 'Guim', 'de', 'la', 'Plana']
# ['Sant', 'Hilari', 'Sacalm']
# ['Sant', 'Hip\xc3\xb2lit', 'de', 'Voltreg\xc3\xa0']
# ['Sant', 'Iscle', 'de', 'Vallalta']
# ['Sant', 'Jaume', 'de', 'Frontany\xc3\xa0']
# ['Sant', 'Jaume', 'de', 'Llierca']
# ['Sant', 'Jaume', 'dels', 'Domenys']
# ['Sant', 'Jaume', "d'Enveja"]
# ['Sant', 'Joan', 'de', 'les', 'Abadesses']
# ['Sant', 'Joan', 'de', 'Mediona']
# ['Sant', 'Joan', 'de', 'Mollet']
# ['Sant', 'Joan', 'Desp\xc3\xad']
# ['Sant', 'Joan', 'de', 'Vilatorrada']
# ['Sant', 'Joan', 'les', 'Fonts']
# ['Sant', 'Jordi', 'Desvalls']
# ['Sant', 'Juli\xc3\xa0', 'de', 'Cerdanyola']
# ['Sant', 'Juli\xc3\xa0', 'de', 'Ramis']
# ['Sant', 'Juli\xc3\xa0', 'de', 'Vilatorta']
# ['Sant', 'Just', 'Desvern']
# ['Sant', 'Lloren\xc3\xa7', 'de', 'la', 'Muga']
# ['Sant', 'Lloren\xc3\xa7', 'de', 'Morunys']
# ['Sant', 'Lloren\xc3\xa7', "d'Hortons"]
# ['Sant', 'Lloren\xc3\xa7', 'Savall']
# ['Sant', 'Mart\xc3\xad', "d'Albars"]
# ['Sant', 'Mart\xc3\xad', 'de', 'Ll\xc3\xa9mena']
# ['Sant', 'Mart\xc3\xad', 'de', 'Mald\xc3\xa0']
# ['Sant', 'Mart\xc3\xad', 'de', 'Tous']
# ['Sant', 'Mart\xc3\xad', 'Sacalm']
# ['Sant', 'Mart\xc3\xad', 'Sarroca']
# ['Sant', 'Mart\xc3\xad', 'Sesgueioles']
# ['Sant', 'Mart\xc3\xad', 'Vell']
# ['Sant', 'Mateu', 'de', 'Bages']
# ['Sant', 'Miquel', 'de', 'Campmajor']
# ['Sant', 'Miquel', 'de', 'Fluvi\xc3\xa0']
# ['Sant', 'Miquel', "d'Ol\xc3\xa8rdola"]
# ['Sant', 'Mori']
# ['Sant', 'Pau', 'de', 'Seg\xc3\xbaries']
# ['Sant', 'Pau', "d'Ordal"]
# ['Santpedor']
# ['Sant', 'Pere', 'de', 'Ribes']
# ['Sant', 'Pere', 'de', 'Riudebitlles']
# ['Sant', 'Pere', 'de', 'Torell\xc3\xb3']
# ['Sant', 'Pere', 'de', 'Vilamajor']
# ['Sant', 'Pere', 'Pescador']
# ['Sant', 'Pere', 'Sallavinera']
# ['Sant', 'Pol', 'de', 'Mar']
# ['Sant', 'Quint\xc3\xad', 'de', 'Mediona']
# ['Sant', 'Quirze', 'de', 'Besora']
# ['Sant', 'Quirze', 'del', 'Vall\xc3\xa8s']
# ['Sant', 'Quirze', 'Safaja']
# ['Sant', 'Ramon']
# ['Sant', 'Sadurn\xc3\xad', "d'Anoia"]
# ['Sant', 'Sadurn\xc3\xad', 'de', "l'Heura"]
# ['Sant', 'Sadurn\xc3\xad', "d'Osormort"]
# ['Sant', 'Salvador', 'de', 'Guardiola']
# ['Sant', 'Vicen\xc3\xa7', 'de', 'Castellet']
# ['Sant', 'Vicen\xc3\xa7', 'dels', 'Horts']
# ['Sant', 'Vicen\xc3\xa7', 'de', 'Montalt']
# ['Sant', 'Vicen\xc3\xa7', 'de', 'Torell\xc3\xb3']
# ['Sarral']
# ['Sarri\xc3\xa0', 'de', 'Ter']
# ['Sarroca', 'de', 'Bellera']
# ['Sarroca', 'de', 'Lleida']
# ['Savall\xc3\xa0', 'del', 'Comtat']
# ['Secuita']
# ['Selva', 'del', 'Camp']
# ['Selva', 'de', 'Mar']
# ['Senan']
# ['S\xc3\xa9nia']
# ['Senterada']
# ['Sentiu', 'de', 'Si\xc3\xb3']
# ['Sentmenat']
# ['Seriny\xc3\xa0']
# ['Ser\xc3\xb2s']
# ['Serra', 'de', 'Dar\xc3\xb3']
# ['Serrateix']
# ['Setcases']
# ['Seu', "d'Urgell"]
# ['Seva']
# ['Sidamon']
# ['Sils']
# ['Sitges']
# ['Siurana']
# ['Sobremunt']
# ['Soler\xc3\xa0s']
# ['Solivella']
# ['Solsona']
# ['Sora']
# ['Sorribes', 'de', 'la', 'Vansa']
# ['Sort']
# ['Soses']
# ['Sudanell']
# ['Sunyer']
# ['S\xc3\xbaria']
# ['Tagamanent']
# ['Talamanca']
# ['Talarn']
# ['Talavera']
# ['Tallada', "d'Empord\xc3\xa0"]
# ['Taradell']
# ['Tarragona']
# ['T\xc3\xa0rrega']
# ['Tarr\xc3\xa9s']
# ['Tarroja', 'de', 'Segarra']
# ['Tav\xc3\xa8rnoles']
# ['Tavertet']
# ['Tei\xc3\xa0']
# ['T\xc3\xa9rmens']
# ['Terrades']
# ['Terrassa']
# ['Tiana']
# ['T\xc3\xadrvia']
# ['Tiurana']
# ['Tivenys']
# ['Tivissa']
# ['Tona']
# ['Tor\xc3\xa0']
# ['Tordera']
# ['Torell\xc3\xb3']
# ['Torms']
# ['Tornabous']
# ['Torrebesses']
# ['Torre', 'de', 'Cabdella']
# ['Torre', 'de', 'Claramunt']
# ['Torre', 'de', 'Fontaubella']
# ['Torre', 'de', "l'Espanyol"]
# ['Torredembarra']
# ['Torrefarrera']
# ['Torrefeta']
# ['Torregrossa']
# ['Torrelameu']
# ['Torrelles', 'de', 'Foix']
# ['Torrelles', 'de', 'Llobregat']
# ['Torrent']
# ['Torres', 'de', 'Segre']
# ['Torre-serona']
# ['Torroella', 'de', 'Fluvi\xc3\xa0']
# ['Torroella', 'de', 'Montgr\xc3\xad']
# ['Torroja', 'del', 'Priorat']
# ['Tortell\xc3\xa0']
# ['Tortosa']
# ['Toses']
# ['Tossa', 'de', 'Mar']
# ['Tremp']
# ['Tuixent']
# ['Ull\xc3\xa0']
# ['Ullastrell']
# ['Ullastret']
# ['Ulldecona']
# ['Ulldemolins']
# ['Ultramort']
# ['Ur\xc3\xbas']
# ['Vacarisses']
# ['Vajol']
# ['Val\xc3\xa8ncia', "d'\xc3\x80neu"]
# ['Vallbona', "d'Anoia"]
# ['Vallbona', 'de', 'les', 'Monges']
# ['Vallcebre']
# ['Vallclara']
# ['Vallfogona', 'de', 'Balaguer']
# ['Vallfogona', 'de', 'Ripoll\xc3\xa8s']
# ['Vallfogona', 'de', 'Riucorb']
# ['Vallgorguina']
# ['Vallirana']
# ['Vall-llobrega']
# ['Vallmoll']
# ['Vallromanes']
# ['Valls']
# ['Valls']
# ['Vandell\xc3\xb2s']
# ['Veciana']
# ['Vendrell']
# ['Ventall\xc3\xb3']
# ['Verd\xc3\xba']
# ['Verges']
# ['Vespella', 'de', 'Gai\xc3\xa0']
# ['Vic']
# ['Vidr\xc3\xa0']
# ['Vidreres']
# ['Vielha']
# ['Vilabella']
# ['Vilabertran']
# ['Vilablareix']
# ['Vilada']
# ['Viladamat']
# ['Viladasens']
# ['Viladecans']
# ['Viladecavalls']
# ['Vilademuls']
# ['Viladrau']
# ['Vilafant']
# ['Vilafranca', 'del', 'Pened\xc3\xa8s']
# ['Vilagrassa']
# ['Vilaju\xc3\xafga']
# ['Vilalba', 'dels', 'Arcs']
# ['Vilalba', 'Sasserra']
# ['Vilaller']
# ['Vilallonga', 'del', 'Camp']
# ['Vilallonga', 'de', 'Ter']
# ['Vilamacolum']
# ['Vilamalla']
# ['Vilamaniscle']
# ['Vilam\xc3\xb2s']
# ['Vilamur']
# ['Vilanant']
# ['Vilanova', 'de', 'Bellpuig']
# ['Vilanova', 'de', 'la', 'Barca']
# ['Vilanova', 'de', "l'Aguda"]
# ['Vilanova', 'del', 'Cam\xc3\xad']
# ['Vilanova', 'del', 'Vall\xc3\xa8s']
# ['Vilanova', 'de', 'Mei\xc3\xa0']
# ['Vilanova', 'de', 'Prades']
# ['Vilanova', 'de', 'Sau']
# ['Vilanova', "d'Escornalbou"]
# ['Vilanova', 'de', 'Segri\xc3\xa0']
# ['Vilanova', 'i', 'la', 'Geltr\xc3\xba']
# ['Vilaplana']
# ['Vilar', "d'Urtx"]
# ['Vila-rodona']
# ['Vila-sacra']
# ['Vila-sana']
# ['Vila-seca']
# ['Vilassar', 'de', 'Dalt']
# ['Vilassar', 'de', 'Mar']
# ['Vila\xc3\xbcr']
# ['Vilaverd']
# ['Vilella', 'Alta']
# ['Vilella', 'Baixa']
# ['Vilob\xc3\xad', 'del', 'Pened\xc3\xa8s']
# ['Vilob\xc3\xad', "d'Onyar"]
# ['Vilopriu']
# ['Vilosell']
# ['Vimbod\xc3\xad']
# ['Vinaixa']
# ['Vinebre']
# ['Vinyols']
# ['Vulpellac']
# ['Xerta']
# La longitud dels noms de pobles catalans va de 1 a 5 paraules.

# %%
# 1.- create an array with all the first uppercase words of the database
from collections import Counter
from collections import defaultdict
starting_words = defaultdict(list)
for linia in clean_all_cities:
    starting_words[' '.join(linia).split(' ')[0]].append(len(linia))


print starting_words['Barberà']
# Out:
# [4, 3]

# %%
# tinc frases del text amb noms de llocs
with open('nt-1.txt') as f:
    haystack = f.read().split()
    num_words = len(haystack)
    possible_cities = []
    for i in range(0,num_words):
        if haystack[i][0].isupper() and haystack[i] in starting_words:
            length_city_name_min = min(starting_words[haystack[i]])
            length_city_name_max = max(starting_words[haystack[i]])
            possible_cities.append([' '.join(haystack[i:i+length_city_name]),length_city_name_min,length_city_name_max])
res = []
clean_cities_string = []
for a in clean_all_cities:
    clean_cities_string.append(' '.join(a))
for s in possible_cities:
    for i in range(s[2],s[1]-1,-1):
        w = ' '.join(s[0].replace(',','').split(' ')[0:i])
        if w in clean_cities_string:
            res.append(w)
print Counter(res)
print 'Ciutat més probable:',Counter(res).most_common(1)
# Out:
# Counter({'Sant Cugat del Vall\xc3\xa8s': 2, 'Matar\xc3\xb3': 1})
# Ciutat més probable: [('Sant Cugat del Vall\xc3\xa8s', 2)]

# %%
#corrector
import re, collections

def words(text): 
    return re.findall('[a-z]+', text.lower()) 

def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

#NWORDS = train(words(file('big.txt').read()))
NWORDS = train(words(file('all_city_names.txt').read()))

alphabet = 'abcçdefghijklmnopqrstuvwxyzàèéiòóúí'

def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in alphabet if b]
   inserts    = [a + c + b     for a, b in splits for c in alphabet]
   return set(deletes + transposes + replaces + inserts)

def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)

def known(words): return set(w for w in words if w in NWORDS)

def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    return max(candidates, key=NWORDS.get)

# %%
correct('Sant Cugat del Vallès i')
# Out:
# 'Sant Cugat del Vall\xc3\xa8s i'

# %%
# Out:
# h
